# %% [markdown]
# # ETF Headlines Sentiment

# %%
# Initial imports
import os
import pandas as pd
from dotenv import load_dotenv
from newsapi import NewsApiClient
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %matplotlib inline
load_dotenv()
# Out:
# True

# %%
# Read your api key environment variable
api_key = os.getenv("NEWS")

# %%
# Create a newsapi client
newsapi = NewsApiClient(api_key=api_key)

# %%
spy_headlines = newsapi.get_everything(q="Apple OR Microsoft",
                                           language="en",
                                           sort_by="relevancy")
spy_headlines['totalResults']
# Out:
# 47369

# %%
# Fetch the SPY - S&P 500 ETF Trust news articles
spy_headlines = newsapi.get_everything(q="Apple OR AAPL OR Microsoft OR MSFT OR Amazon OR AMZN OR Facebook OR FB OR Tesla OR TSLA OR Google OR GOOGL OR GOOG OR Berkshire Hathaway OR Johnson & Johnson OR JNJ OR JP Morgan OR JPM",
                                           language="en",
                                           sort_by="relevancy")
spy_headlines['totalResults']
# Out:
# 214250

# %%
# Fetch the XLF - Financial Sector news articles
finance_headlines = newsapi.get_everything(q="American Financial Sector OR Bank of America OR JP Morgan OR Wells Fargo OR Morgan Stanley OR Berkshire Hathaway OR Goldman Sachs OR Charles Schwab OR Fidelity", 
                                           language="en",
                                           sort_by="relevancy")
finance_headlines
# Out:
# {'status': 'ok',
#  'totalResults': 10688,
#  'articles': [{'source': {'id': None, 'name': 'MarketWatch'},
#    'author': 'Philip van Doorn',
#    'title': 'Deep Dive: Banks are back — almost half of 15 large U.S. banks are expected to increase quarterly profit',
#    'description': 'Bank stocks have been revived after a long decline during the coronavirus pandemic.',
#    'url': 'https://www.marketwatch.com/story/banks-are-back-almost-half-of-15-large-u-s-banks-are-expected-to-increase-quarterly-profit-11610395992',
#    'urlToImage': 'https://images.mktw.net/im-283391/social',
#    'publishedAt': '2021-01-12T12:15:00Z',
#    'content': 'Investors have been enthusiastic about large U.S. banks the stocks have been soaring. And according to industry analysts, a steepening interest-rate curve, the resilience of consumers and a strong po… [+7196 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Theo Golden',
#    'title': 'GOLDMAN SACHS: Buy these 50 under-owned stocks that will roar higher as growth and inflation lift off in 2021',
#    'description': 'Summary List PlacementValue stocks are set to outperform in 2021, as global economic activity recovers and inflation expectations pick up, continuing the historic rotation away from growth stocks that started in the fourth quarter of 2020.\nEven with at least …',
#    'url': 'https://www.businessinsider.com/stocks-to-buy-50-under-owned-recovery-value-goldman-sachs-2021-1',
#    'urlToImage': 'https://i.insider.com/5ffd9844bde805001980c54d?width=1200&format=jpeg',
#    'publishedAt': '2021-01-12T15:18:24Z',
#    'content': 'Value stocks are set to outperform in 2021, as global economic activity recovers and inflation expectations pick up, continuing the historic rotation away from growth stocks that started in the fourt… [+4716 chars]'},
#   {'source': {'id': None, 'name': 'Lifehacker.com'},
#    'author': 'Mike Winters on Two Cents, shared by Mike Winters to Lifehacker',
#    'title': 'How to Handle an Unexpected Financial Windfall',
#    'description': 'A financial windfall can come in many forms—inheritance, from a trust, stock options, winning the lottery, and to a lesser extent, government relief checks. It’s very common for people to spend much or all of a windfall right away, leaving them little to show…',
#    'url': 'https://twocents.lifehacker.com/how-to-handle-an-unexpected-financial-windfall-1846001701',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/riurrjjsbroiqtuy5u3f.jpg',
#    'publishedAt': '2021-01-06T19:30:00Z',
#    'content': 'A financial windfall can come in many formsinheritance, from a trust, stock options, winning the lottery, and to a lesser extent, government relief checks. Its very common for people to spend much or… [+4551 chars]'},
#   {'source': {'id': None, 'name': 'Lifehacker.com'},
#    'author': 'Mike Winters on Two Cents, shared by Mike Winters to Lifehacker',
#    'title': 'Quick and Easy Financial Resolutions for 2021',
#    'description': 'New Year’s resolutions typically fail when they’re sweepingly ambitious—which can really hurt you when you’re focused on managing your money. Instead, focus on\xa0quick, easy-to-manage personal finance tasks that will put you in good shape for 2021—like the ones…',
#    'url': 'https://twocents.lifehacker.com/quick-and-easy-financial-resolutions-for-2021-1845963045',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/mc1pl9u2apvoxudm8o0u.jpg',
#    'publishedAt': '2020-12-29T19:45:00Z',
#    'content': 'New Years resolutions typically fail when theyre sweepingly ambitiouswhich can really hurt you when youre focused on managing your money. Instead, focus on\xa0quick, easy-to-manage personal finance task… [+5002 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Jennifer Hughes',
#    'title': 'Breakingviews - China’s gravy train will bypass Wall Street - Reuters UK',
#    'description': 'Investment bankers will have a great chance in 2021 to apply their well-honed skills at talking up opportunities and downplaying league tables. The easiest money from selling Chinese shares in New York is destined to fade. And profitably pushing further onto …',
#    'url': 'https://uk.reuters.com/article/us-china-ipo-breakingviews-idUKKBN29501S',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20201231&t=2&i=1546221251&r=LYNXMPEGBU00U&w=800',
#    'publishedAt': '2020-12-31T01:01:00Z',
#    'content': 'An investor looks at an electronic board showing stock information at a brokerage house in Shanghai, China July 6, 2018. REUTERS/Aly Song - RC1CDAB1A6B0\r\nHONG KONG (Reuters Breakingviews) - Investmen… [+2974 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Jennifer Hughes',
#    'title': 'Breakingviews - China’s gravy train will bypass Wall Street - Reuters',
#    'description': 'Investment bankers will have a great chance in 2021 to apply their well-honed skills at talking up opportunities and downplaying league tables. The easiest money from selling Chinese shares in New York is destined to fade. And profitably pushing further onto …',
#    'url': 'https://www.reuters.com/article/us-china-ipo-breakingviews-idUSKBN29501S',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20201231&t=2&i=1546221251&r=LYNXMPEGBU00U&w=800',
#    'publishedAt': '2020-12-31T00:59:00Z',
#    'content': 'An investor looks at an electronic board showing stock information at a brokerage house in Shanghai, China July 6, 2018. REUTERS/Aly Song - RC1CDAB1A6B0\r\nHONG KONG (Reuters Breakingviews) - Investmen… [+2974 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Devik Jain',
#    'title': 'Futures grind higher as Democrats win Senate control - Reuters UK',
#    'description': 'U.S. stock index futures climbed on Thursday as expectations of more pandemic aid under a Democrat-controlled U.S. Congress lifted the mood ahead of jobs data, which is expected to show a rise in weekly claims.',
#    'url': 'https://uk.reuters.com/article/us-usa-stocks-idUSKBN29C1KT',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210107&t=2&i=1546953669&r=LYNXMPEH060U1&w=800',
#    'publishedAt': '2021-01-07T12:17:00Z',
#    'content': '(Reuters) - U.S. stock index futures climbed on Thursday as expectations of more pandemic aid under a Democrat-controlled U.S. Congress lifted the mood ahead of jobs data, which is expected to show a… [+1908 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Devik Jain',
#    'title': 'Futures grind higher as Democrats win Senate control - Reuters',
#    'description': 'U.S. stock index futures climbed on Thursday as expectations of more pandemic aid under a Democrat-controlled U.S. Congress lifted the mood ahead of jobs data, which is expected to show a rise in weekly claims.',
#    'url': 'https://www.reuters.com/article/us-usa-stocks-idUSKBN29C1KT',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210107&t=2&i=1546953669&r=LYNXMPEH060U1&w=800',
#    'publishedAt': '2021-01-07T12:17:00Z',
#    'content': '(Reuters) - U.S. stock index futures climbed on Thursday as expectations of more pandemic aid under a Democrat-controlled U.S. Congress lifted the mood ahead of jobs data, which is expected to show a… [+1908 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Devik Jain',
#    'title': 'US STOCKS-Futures grind higher as Democrats win Senate control - Reuters UK',
#    'description': 'U.S. stock index futures climbed on Thursday as expectations of more pandemic aid under a Democrat-controlled U.S. Congress lifted the mood ahead of jobs data, which is expected to show a rise in weekly claims.',
#    'url': 'https://uk.reuters.com/article/us-usa-stocks-idUKKBN29C1KT',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210107&t=2&i=1546953669&r=LYNXMPEH060U1&w=800',
#    'publishedAt': '2021-01-07T12:10:00Z',
#    'content': '(Reuters) - U.S. stock index futures climbed on Thursday as expectations of more pandemic aid under a Democrat-controlled U.S. Congress lifted the mood ahead of jobs data, which is expected to show a… [+1908 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': "Fed's Evans calls for possible revamp of U.S. financial regulation - Reuters Africa",
#    'description': 'Chicago Federal Reserve President Charles Evans on Tuesday raised the possibility that U.S. financial regulation and supervision may be due for an overhaul, given the new reality that interest rates are likely to be low for a long time.',
#    'url': 'https://www.reuters.com/article/us-usa-fed-evans-idUSKBN29A2I0',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210105&t=2&i=1546708383&r=LYNXMPEH041BX&w=800',
#    'publishedAt': '2021-01-05T20:48:00Z',
#    'content': 'By Reuters Staff\r\nFILE PHOTO: Chicago Federal Reserve Bank President Charles Evans looks on during the Global Interdependence Center Members Delegation Event in Mexico City, Mexico, February 27, 2020… [+2241 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'Take Five: The great reflation - Reuters',
#    'description': "One trade is gripping markets in the early days of 2021: reflation - nowhere more evident than in bonds, where U.S. 10-year Treasury yields topped 1% on Georgia's Senate runoff results.",
#    'url': 'https://www.reuters.com/article/us-global-markets-themes/take-five-the-great-reflation-idUSKBN29D1II',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210108&t=2&i=1547099095&r=LYNXMPEH070OP&w=800',
#    'publishedAt': '2021-01-08T12:18:00Z',
#    'content': 'By Reuters Staff\r\n1/BIDEN BET\r\nFILE PHOTO: A trader at the New York Stock Exchange works as markets continue to react to the coronavirus disease (COVID-19) inside of the NYSE in New York, U.S., March… [+4284 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'RPT-GRAPHIC-Take Five: The great reflation - Reuters',
#    'description': "One trade is gripping markets in the early days of 2021: reflation - nowhere more evident than in bonds, where U.S. 10-year Treasury yields topped 1% on Georgia's Senate runoff results.",
#    'url': 'https://www.reuters.com/article/global-markets-themes/rpt-graphic-take-five-the-great-reflation-idUSL1N2JM0ES',
#    'urlToImage': 'https://s1.reutersmedia.net/resources_v2/images/rcom-default.png?w=800',
#    'publishedAt': '2021-01-11T08:03:00Z',
#    'content': 'By Reuters Staff\r\n(repeats story from Friday, adds link to China story)\r\n1/BIDEN BET\r\nOne trade is gripping markets in the early days of 2021: reflation - nowhere more evident than in bonds, where U.… [+4633 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'GRAPHIC-Take Five: The great reflation - Reuters',
#    'description': "One trade is gripping markets in the early days of 2021: reflation - nowhere more evident than in bonds, where U.S. 10-year Treasury yields topped 1% on Georgia's Senate runoff results.",
#    'url': 'https://www.reuters.com/article/global-markets-themes/graphic-take-five-the-great-reflation-idUSL8N2JJ14F',
#    'urlToImage': 'https://s1.reutersmedia.net/resources_v2/images/rcom-default.png?w=800',
#    'publishedAt': '2021-01-08T12:08:00Z',
#    'content': 'By Reuters Staff\r\n1/BIDEN BET\r\nOne trade is gripping markets in the early days of 2021: reflation - nowhere more evident than in bonds, where U.S. 10-year Treasury yields topped 1% on Georgias Senate… [+4501 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Rickie Houston, CEPF',
#    'title': 'Chase You Invest review: Choose between DIY trading and robo-advice',
#    'description': 'Summary List Placement<ul>\n<li>Chase You Invest is an online brokerage that offers both DIY trading and managed accounts. It lets current Chase Bank customers connect all of their accounts in the same place.</li>\n<li>Chase You Invest offers commission-free tr…',
#    'url': 'https://www.businessinsider.com/personal-finance/chase-you-invest-review',
#    'urlToImage': 'https://i.insider.com/5fecb7deb7ab82001943e9f5?width=1200&format=jpeg',
#    'publishedAt': '2021-01-04T21:56:39Z',
#    'content': 'Personal Finance Insider writes about products, strategies, and tips to help you make smart decisions with your money. We may receive a small commission from our partners, like American Express, but … [+5881 chars]'},
#   {'source': {'id': 'wired', 'name': 'Wired'},
#    'author': 'Arielle Pardes',
#    'title': 'Yet Another Year of Venture Capital Being Really White',
#    'description': 'After a year of protests against racial inequality and industry vows to do better, Black founders are still getting left out of Silicon Valley’s financial engine.',
#    'url': 'https://www.wired.com/story/venture-capital-2020-still-really-white/',
#    'urlToImage': '',
#    'publishedAt': '2020-12-29T12:00:00Z',
#    'content': 'Last year, Vern Howard met with a number of venture capitalists to pitch his digital events startup, Hallo. The meetings did not always go well. In the office of one prominent VC, Howard, who is Blac… [+3979 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Hayley Cuccinello',
#    'title': 'These are the 29 most generous billionaires in America',
#    'description': 'Summary List Placement"If the public sector will not take \'personal responsibility\' for providing an adequate safety net for those in distress, private philanthropy must do so."\nThat\'s the charitable mandate George Kaiser — one of America\'s most generous (and…',
#    'url': 'https://www.businessinsider.com/most-generous-billionaires-in-america-philanthropy-charitable-giving-2020-12',
#    'urlToImage': 'https://i.insider.com/5fee0f749ff41f001883f963?width=1200&format=jpeg',
#    'publishedAt': '2020-12-31T19:30:28Z',
#    'content': '"If the public sector will not take \'personal responsibility\' for providing an adequate safety net for those in distress, private philanthropy must do so."\r\nThat\'s the charitable mandate George Kaise… [+2256 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Liz Knueven',
#    'title': 'The best personal loans of 2021',
#    'description': "Summary List PlacementHere are the best personal loans right now:\nRates in this post are current as of 01/13/2021.\n<table>\n<tr>\n<td>Lender</td>\n<td>Rates</td>\n<td>Editor's Note</td>\n</tr>\n<tr>\n<td>Lightstream\r\n</td>\n<td>4.99% to 19.99%* APR with AutoPay (rate…",
#    'url': 'https://www.businessinsider.com/personal-finance/best-personal-loans',
#    'urlToImage': 'https://i.insider.com/5fbd812150e71a00115573c8?width=1200&format=jpeg',
#    'publishedAt': '2021-01-13T22:24:29Z',
#    'content': 'Personal Finance Insider writes about products, strategies, and tips to help you make smart decisions with your money. We may receive a small commission from our partners, like American Express, but … [+8751 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Danny Crichton',
#    'title': 'Activist hedge fund manager Daniel Loeb takes on Intel, plans launch of new VC fund',
#    'description': 'Third Point, the activist hedge fund run by Daniel Loeb, is busy in the waning days of 2020. It’s had great returns despite huge turbulence early in the pandemic — Reuters says that it is up 12.3% for the year as of earlier this month — and the firm clearly s…',
#    'url': 'http://techcrunch.com/2020/12/30/third-point-intel-venture-fund/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2020/12/GettyImages-187750775.jpg?w=601',
#    'publishedAt': '2020-12-30T16:39:23Z',
#    'content': 'Third Point, the activist hedge fund run by Daniel Loeb, is busy in the waning days of 2020. Its had great returns despite huge turbulence early in the pandemic Reuters says that it is up 12.3% for t… [+1656 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Anna Szymanski',
#    'title': 'Breakingviews - Latin America debt will hit post-crisis sweet spot - Reuters',
#    'description': 'Latin America’s luck will change. Pandemic lockdowns caused more regional corporations to default between early May and June. But yield-starved investors will ignore some of these risks.',
#    'url': 'https://www.reuters.com/article/us-latam-debt-breakingviews-idUSKBN28W1U4',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20201222&t=2&i=1545449839&r=LYNXMPEGBL13L&w=800',
#    'publishedAt': '2020-12-22T15:29:00Z',
#    'content': "Brazil's President Jair Bolsonaro gestures during the launching ceremony of the Voo Simples program, which are a set of measures to modernize rules and reduce costs in the general aviation sectors, a… [+3008 chars]"},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'UPDATE 1-Telefonica sells mobile phone masts to American Towers for $9.4 bln - Reuters',
#    'description': 'Spanish telecom company Telefonica said on Wednesday it had agreed to sell its mobile phone masts owned by its Telxius division in Europe and Latin America to American Towers for 7.7 billion euros ($9.41 billion) in cash.',
#    'url': 'https://www.reuters.com/article/telefonica-ma-american-tower/update-1-telefonica-sells-mobile-phone-masts-to-american-towers-for-9-4-bln-idUSL1N2JO0F1',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210113&t=2&i=1547593513&r=LYNXMPEH0C0EA&w=800',
#    'publishedAt': '2021-01-13T08:09:00Z',
#    'content': "By Reuters Staff\r\nFILE PHOTO: The logo of Telefonica is seen on company's headquarters in Bogota, Colombia May 28, 2019. REUTERS/Luisa Gonzalez\r\nMADRID (Reuters) - Spanish telecom company Telefonica … [+1630 chars]"}]}

# %%
# Fetch the XLK - Tecnology Sector news articles
tech_headlines = newsapi.get_everything(q="americantechnologysector OR technology disruption OR cybersecurity OR semiconductors OR Apple OR Microsoft OR AAPL OR MSFT OR Visa OR Nvidia OR NVDA OR Paypal OR Salesforce OR CRM",
                                           language="en",
                                           sort_by="relevancy")
tech_headlines
# Out:
# {'status': 'ok',
#  'totalResults': 142024,
#  'articles': [{'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Danny Crichton',
#    'title': '2021 will be a calmer year for semiconductors and chips (except for Intel)',
#    'description': 'If ever there was a typically quiet tech industry that seemed to drive massive headlines this year, it was semiconductors. From record-setting M&A purchases to prodigious venture capital financing, the decline of major players and huge international trade fig…',
#    'url': 'http://techcrunch.com/2020/12/28/semiconductors-in-2021/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2020/12/GettyImages-184912447.jpg?w=605',
#    'publishedAt': '2020-12-28T17:01:34Z',
#    'content': 'If ever there was a typically quiet tech industry that seemed to drive massive headlines this year, it was semiconductors. From record-setting M&amp;A purchases to prodigious venture capital financin… [+5782 chars]'},
#   {'source': {'id': None, 'name': 'New York Times'},
#    'author': 'Nicole Perlroth',
#    'title': 'Russia Used Microsoft Resellers in Hacking',
#    'description': 'Evidence from the security firm CrowdStrike suggests that companies that sell software on behalf of Microsoft were used to break into Microsoft’s Office 365 customers.',
#    'url': 'https://www.nytimes.com/2020/12/24/us/russia-microsoft-resellers-cyberattacks.html',
#    'urlToImage': 'https://static01.nyt.com/images/2020/12/24/multimedia/24Hack-1/24Hack-1-facebookJumbo.jpg',
#    'publishedAt': '2020-12-25T03:59:58Z',
#    'content': 'But the CrowdStrike discovery shows how the Russian hackers used its resellers to target its customers indirectly. CrowdStrike said in a blog post on Wednesday that hackers tried to read the companys… [+1617 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Rhett Jones',
#    'title': 'Judge Tosses Apple Lawsuit Against iPhone Emulator in Big Victory for Security Research',
#    'description': 'Security researchers looking to get under the hood of technology in order to improve it received a pleasant victory on Tuesday when a federal judge in Florida decided to throw out Apple’s copyright violation claims against the maker of virtual iPhone software…',
#    'url': 'https://gizmodo.com/judge-tosses-apple-lawsuit-against-iphone-emulator-in-b-1845967318',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/svpuf54a1brez3cco71b.jpg',
#    'publishedAt': '2020-12-30T16:55:00Z',
#    'content': 'Security researchers looking to get under the hood of technology in order to improve it received a pleasant victory on Tuesday when a federal judge in Florida decided to throw out Apples copyright vi… [+2436 chars]'},
#   {'source': {'id': 'engadget', 'name': 'Engadget'},
#    'author': 'Cherlynn Low',
#    'title': 'Google and Microsoft chat accessibility in tech',
#    'description': 'Plenty of new toys are being announced across all kinds of categories at CES 2021, including a number of accessibility-focused products. But it isn’t just within niche areas that companies should be thinking about accessibility; inclusive design should be con…',
#    'url': 'https://www.engadget.com/google-microsoft-accessibility-tech-xr-disabilities-inclusive-design-205252961.html',
#    'urlToImage': 'https://o.aolcdn.com/images/dims?resize=1200%2C630&crop=1200%2C630%2C0%2C0&quality=95&image_uri=https%3A%2F%2Fs.yimg.com%2Fos%2Fcreatr-uploaded-images%2F2021-01%2Fe964c930-5516-11eb-b65e-2b29ac5fd6b4&client=amp-blogside-v2&signature=dc2754babcb50502933ad8000e61fa577a36ec16',
#    'publishedAt': '2021-01-12T20:52:52Z',
#    'content': 'Plenty of new toys are being announced across all kinds of categories at CES 2021, including a number of accessibility-focused products. But it isnt just within niche areas that companies should be t… [+476 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Natasha Mascarenhas',
#    'title': 'The end of Plaid-Visa, and Palantir’s growing startup mafia',
#    'description': 'Hello and welcome back to\xa0Equity, TechCrunch’s venture-capital-focused podcast, where we unpack the numbers behind the headlines. This week we — Natasha and Danny and Alex and Grace — had a lot to get through, as the news volume in early 2021 has been rapid, …',
#    'url': 'http://techcrunch.com/2021/01/14/the-end-of-plaid-visa-and-palantirs-growing-startup-mafia/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2019/12/equity-podcast-2019-phone-1-4-e1578089278201.jpg?w=350',
#    'publishedAt': '2021-01-14T22:59:29Z',
#    'content': 'Hello and welcome back to\xa0Equity, TechCrunchs venture-capital-focused podcast, where we unpack the numbers behind the headlines.\r\nThis week we — Natasha and Danny and Alex and Grace — had a lot to ge… [+1003 chars]'},
#   {'source': {'id': 'engadget', 'name': 'Engadget'},
#    'author': 'Jon Fingas',
#    'title': "President Biden appoints 'world-class' cybersecurity team in wake of hacks",
#    'description': 'President Biden is elevating the importance of cybersecurity in light of the SolarWinds hack that compromised multiple government institutions. Reuters reports that Biden has appointed (and will soon appoint) a host of officials well-versed in cybersecurity. …',
#    'url': 'https://www.engadget.com/president-biden-appoints-cybersecurity-team-163549381.html',
#    'urlToImage': 'https://s.yimg.com/os/creatr-uploaded-images/2021-01/f938e750-5cc9-11eb-bbef-3bad987c5bdf',
#    'publishedAt': '2021-01-22T16:35:49Z',
#    'content': 'President Biden is elevating the importance of cybersecurity in light of the SolarWinds hack that compromised multiple government institutions. Reutersreports that Biden has appointed (and will soon … [+2384 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Zack Whittaker',
#    'title': 'FBI, NSA say hacks on US federal agencies ‘likely Russian in origin’',
#    'description': 'The U.S. government says hackers “likely Russian in origin” are responsible for breaching the networks of at least 10 U.S. federal agencies and several major tech companies, including FireEye and Microsoft. In a joint statement published Tuesday, the FBI, the…',
#    'url': 'http://techcrunch.com/2021/01/05/fbi-nsa-says-hacks-on-us-federal-agencies-likely-russian-in-origin/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2021/01/GettyImages-1230263778.jpg?w=600',
#    'publishedAt': '2021-01-05T20:55:23Z',
#    'content': 'The U.S. government says hackers “likely Russian in origin” are responsible for breaching the networks of at least 10 U.S. federal agencies and several major tech companies, including FireEye and Mic… [+2149 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Lewis Krauskopf',
#    'title': 'Tech shares could retake market reins as earnings heat up - Reuters',
#    'description': 'A bevy of major U.S. earnings reports next week led by Apple, Microsoft and Facebook could help technology and growth stocks reassert their dominance after a recent run by banks, energy and other potential beneficiaries of an economic reopening.',
#    'url': 'https://www.reuters.com/article/us-usa-stocks-weekahead-idUSKBN29R2BI',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210122&t=2&i=1548745046&r=LYNXMPEH0L1BS&w=800',
#    'publishedAt': '2021-01-22T18:03:00Z',
#    'content': 'NEW YORK (Reuters) - A bevy of major U.S. earnings reports next week led by Apple, Microsoft and Facebook could help technology and growth stocks reassert their dominance after a recent run by banks,… [+4020 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Ingrid Lunden',
#    'title': 'IBM leads U.S. patent list for 2020 as total numbers decline 1% in pandemic year to 352,000',
#    'description': 'One year in, the Covid-19 global health pandemic continues to have something of a dragging effect on many aspects of life, but today a key bellwether for how technology is developing underscored how the industry continues to march on. The number of patents gr…',
#    'url': 'http://techcrunch.com/2021/01/12/ibm-leads-u-s-patent-list-for-2020-as-total-numbers-decline-1-in-pandemic-year-to-352000/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2018/10/GettyImages-187290878.jpg?w=600',
#    'publishedAt': '2021-01-12T11:21:16Z',
#    'content': 'One year in, the Covid-19 global health pandemic continues to have something of a dragging effect on many aspects of life, but today a key bellwether for how technology is developing underscored how … [+5930 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Kirsten Korosec',
#    'title': 'Microsoft invests in Cruise in new $2 billion round',
#    'description': 'Cruise has raised $2 billion in a new equity round that has pushed its valuation up to $30 billion and delivered Microsoft as a cloud computing partner and investor. GM, Honda and other institutional investors have also put more capital into Cruise as the aut…',
#    'url': 'http://techcrunch.com/2021/01/19/microsoft-invests-in-cruise-in-new-2-billion-round/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2021/01/Cruise-MSFT-Logo-Lockup.jpg?w=600',
#    'publishedAt': '2021-01-19T14:04:15Z',
#    'content': 'Cruise has raised $2 billion in a new equity round that has pushed its valuation up to $30 billion and delivered Microsoft as an investor and partner.\r\nGM, Honda and other institutional investors hav… [+1983 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Taylor Lyles',
#    'title': 'The best apps, games, and entertainment for all of your new tech in 2020',
#    'description': 'Here at The Verge, we want to help, so we’ve put together lists of our favorite apps, games, and shows from Apple, Google, Microsoft, Amazon, and a plethora of companies.',
#    'url': 'https://www.theverge.com/22167508/best-2020-new-apps-games-entertainment-tv-top-list-recommendations',
#    'urlToImage': 'https://cdn.vox-cdn.com/thumbor/bpIpPErCJkAUcgwIetOguxfEufY=/0x146:2040x1214/fit-in/1200x630/cdn.vox-cdn.com/uploads/chorus_asset/file/22175947/acastro_201216_4345_bestOfApps_0001.jpg',
#    'publishedAt': '2020-12-22T15:09:38Z',
#    'content': 'Photo by Alex Castro / The Verge\r\n\n \n\n Our favorites for all your new devices While it’s really great to get a new tech device — a phone, a laptop, a game console, a Kindle, or a TV — as a gift, it’s… [+633 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Cameron Faulkner',
#    'title': 'Vizio’s 65-inch 4K QLED TV is cheaper than ever at Best Buy',
#    'description': 'You can pick up a discounted Vizio 65-inch M-series TV with a QLED screen and variable refresh rate support. We’ve also included deals on Microsoft 365 and Apple AirPods Pro.',
#    'url': 'https://www.theverge.com/good-deals/2020/12/28/22202842/vizio-65-inch-4k-qled-tv-microsoft-365-airpods-pro-deal-sale-amazon-best-buy',
#    'urlToImage': 'https://cdn.vox-cdn.com/thumbor/K4sIgNGIW8kXRlXSBdy60uf3_Gs=/0x88:1217x725/fit-in/1200x630/cdn.vox-cdn.com/uploads/chorus_asset/file/22200293/vizio_voice.jpg',
#    'publishedAt': '2020-12-28T16:25:36Z',
#    'content': 'Not after a TV? There are great deals on earbuds and Microsoft 365\r\nIf you buy something from a Verge link, Vox Media may earn a commission. See our ethics statement.\r\nPhoto: Vizio\r\nThis story is par… [+2518 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Anthony Ha',
#    'title': 'Daily Crunch: Microsoft backs Cruise',
#    'description': 'Autonomous vehicle company Cruise raises a $2 billion new round, Netflix keeps growing and WhatsApp faces more privacy concerns. This is your Daily Crunch for January 19, 2021. The big story: Microsoft backs Cruise Cruise announced today that it has raised $2…',
#    'url': 'http://techcrunch.com/2021/01/19/daily-crunch-microsoft-backs-cruise/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2020/01/Cruise-Track-3-in-Seattle.jpg?w=600',
#    'publishedAt': '2021-01-19T23:12:20Z',
#    'content': 'Autonomous vehicle company Cruise raises a $2 billion new round, Netflix keeps growing and WhatsApp faces more privacy concerns. This is your Daily Crunch for January 19, 2021.\r\nThe big story: Micros… [+3115 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Catherine Shu',
#    'title': 'From crypto trading and home workouts to EV batteries and microLED displays, CES’ Taiwan startups cover a wide range of tech',
#    'description': 'For the past three years, the Taiwan Ministry of Science and Technology (MOST) has brought startups to CES . This year, its virtual pavilion, organized with Taiwan Tech Arena, is hosting 100 startups, organized into five categories: Smart Living, Tech for Goo…',
#    'url': 'http://techcrunch.com/2021/01/12/from-crypto-trading-and-home-workouts-to-ev-batteries-and-microled-displays-ces-taiwan-startups-cover-a-wide-range-of-tech/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2021/01/GettyImages-861177234.jpg?w=600',
#    'publishedAt': '2021-01-12T13:25:30Z',
#    'content': 'For the past three years, the Taiwan Ministry of Science and Technology (MOST) has brought startups to CES . This year, its virtual pavilion, organized with Taiwan Tech Arena, is hosting 100 startups… [+8036 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Cameron Faulkner',
#    'title': 'Acer’s latest gaming monitors include its first with HDMI 2.1',
#    'description': 'Acer has announced three new gaming monitors at CES 2021, including the Nitro XV28 that supports HDMI 2.1 to display 4K resolution at up to 120Hz. It also showed off the Predator XB27 and XB32, two monitors with HDR and support for Nvidia G-Sync technology.',
#    'url': 'https://www.theverge.com/2021/1/7/22216979/acer-gaming-monitors-nitro-predator-xv28-xb27-xb32-ces-2021-may-price-specs-hdmi-21',
#    'urlToImage': 'https://cdn.vox-cdn.com/thumbor/z30PY_wDUjZvAO_URliBlq8lMYE=/0x146:2040x1214/fit-in/1200x630/cdn.vox-cdn.com/uploads/chorus_asset/file/22219662/nitroxv28.jpg',
#    'publishedAt': '2021-01-07T18:00:00Z',
#    'content': 'The Nitro XV28 will support up to 4K at 120Hz\r\nThe Nitro XV28 is Acers first monitor with HDMI 2.1\r\nAcer\r\nAs the first part of Acers CES 2021 announcements, the company shared that it has three new g… [+3430 chars]'},
#   {'source': {'id': None, 'name': 'StockNews.com'},
#    'author': 'Imon Ghosh',
#    'title': 'Why Apple Stock Will Continue to Outperform in 2021',
#    'description': "A big jump in orders and rapid growth in international sales in its last reported quarter has raised investor optimism about Apple Inc.'s (AAPL) future performance.",
#    'url': 'https://stocknews.com/news/aapl-dell-hpq-phg-why-apple-stock-will-continue-to-outperform-in-2021/',
#    'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1609965435-ScreenShot2021-01-06at33617PM.png',
#    'publishedAt': '2021-01-06T20:37:22Z',
#    'content': 'January\r\n6, 2021\r\n5 min read\r\nThis story originally appeared on StockNewsThe world’s highest-selling 5G smartphone company, Apple Inc. (AAPL\xa0-\xa0Get Rating), delivered impressive numbers in its last qu… [+5728 chars]'},
#   {'source': {'id': 'engadget', 'name': 'Engadget'},
#    'author': 'Engadget',
#    'title': "The Morning After: Microsoft is pulling the plug on 'Minecraft Earth'",
#    'description': 'If existing styles of wireless earbuds have never quite worked for you, Bose is ready to try a new design. These wireless Sport Open Earbuds don’t go in or over your ear canal. Instead they sit above it, allowing you to get the audio and still hear sounds of …',
#    'url': 'https://www.engadget.com/minecraft-earth-tma-122610380.html',
#    'urlToImage': 'https://o.aolcdn.com/images/dims?resize=1200%2C630&crop=1200%2C630%2C0%2C0&quality=95&image_uri=https%3A%2F%2Fs.yimg.com%2Fos%2Fcreatr-uploaded-images%2F2021-01%2F47f0f3f0-5019-11eb-bfea-4bf6916a87de&client=amp-blogside-v2&signature=e5c1b2503474e32948b7f7bcddd69dabeff498b8',
#    'publishedAt': '2021-01-06T12:26:10Z',
#    'content': 'If existing styles of wireless earbuds have never quite worked for you, Bose is ready to try a new design. These wireless Sport Open Earbuds don’t go in or over your ear canal. Instead they sit above… [+3495 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Stephen Nellis',
#    'title': 'Qualcomm eyes challenge to Apple, Intel with $1.4 billion deal for chip startup - Reuters',
#    'description': "Qualcomm Inc on Wednesday said it will acquire Nuvia Inc, a chip startup founded by Apple Inc veterans, for $1.4 billion, with plans to put the firm's technology into its smartphone, laptop and automotive processors.",
#    'url': 'https://www.reuters.com/article/us-qualcomm-m-a-nuvia/qualcomm-eyes-challenge-to-apple-intel-with-1-4-billion-deal-for-chip-startup-idUSKBN29I1OJ',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210113&t=2&i=1547631453&r=LYNXMPEH0C0Y5&w=800',
#    'publishedAt': '2021-01-13T13:07:00Z',
#    'content': '(Reuters) - Qualcomm Inc on Wednesday said it will acquire Nuvia Inc, a chip startup founded by Apple Inc veterans, for $1.4 billion, with plans to put the firms technology into its smartphone, lapto… [+2354 chars]'},
#   {'source': {'id': 'engadget', 'name': 'Engadget'},
#    'author': 'Mariella Moon',
#    'title': 'SolarWinds hackers also targeted security specialist Malwarebytes',
#    'description': 'American security company Malwarebytes has revealed that it was targeted by the same “nation state actor implicated in SolarWinds breach.” The firm says it doesn’t use SolarWinds’ IT software, which served as the hackers’ entryway into the systems of all the …',
#    'url': 'https://www.engadget.com/solarwinds-hackers-targeted-malwarebytes-110537912.html',
#    'urlToImage': 'https://o.aolcdn.com/images/dims?resize=1200%2C630&crop=1200%2C630%2C0%2C0&quality=95&image_uri=https%3A%2F%2Fs.yimg.com%2Fos%2Fcreatr-images%2F2020-04%2F5228d340-88ca-11ea-bddb-1a9c51d5facf&client=amp-blogside-v2&signature=aecc28976e75ba43cea0b6009be24be8c29c0b53',
#    'publishedAt': '2021-01-20T11:35:37Z',
#    'content': 'Malwarebytes assures its anti-malware users, however, that it conducted an extensive investigation and determined that the attackers only gained access to a limited subset of internal company emails.… [+732 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Matthew DeBord',
#    'title': "The Apple Car would wreck Apple, and Tesla's incredibly volatile history shows why (TSLA, AAPL)",
#    'description': 'Summary List PlacementIn case you missed it, the Apple Car is back. In the past few weeks, both Reuters and Bloomberg have reported that something is up with what Apple is calling "Project Titan," after years of starts and stops. There have even been confusin…',
#    'url': 'https://www.businessinsider.com/teslas-history-shows-why-the-apple-car-would-wreck-apple-2021-1',
#    'urlToImage': 'https://i.insider.com/5fe25c2ca644880018193012?width=1200&format=jpeg',
#    'publishedAt': '2021-01-09T14:52:00Z',
#    'content': 'In case you missed it, the Apple Car is back. In the past few weeks, both Reuters and Bloomberg have reported that something is up with what Apple is calling "Project Titan," after years of starts an… [+6635 chars]'}]}

# %%
# Fetch the XTL - Telecom Sector news articles
telecom_headlines = newsapi.get_everything(q="AmericanTelecommunicationsSector OR IYZ OR IRDM OR 5G OR INSG OR VIAV OR CALX OR MSFT OR Visa OR Nvidia OR NVDA OR Paypal OR Salesforce OR CRM",
                                           language="en",
                                           sort_by="relevancy")
telecom_headlines
# Out:
# {'status': 'ok',
#  'totalResults': 27086,
#  'articles': [{'source': {'id': 'engadget', 'name': 'Engadget'},
#    'author': 'Cherlynn Low',
#    'title': "Lenovo's Yoga 7 AiO can flip between landscape and portrait modes",
#    'description': 'It’s time again for Lenovo to update its products, and brace yourselves, because there’s a ton of them. As part of its CES 2021 newspalooza, the company is announcing a slew of new devices like laptops, tablets, all-in-ones and monitors. Of note are the new I…',
#    'url': 'https://www.engadget.com/lenovo-ideapad-5g-14-16-amd-intel-yoga-aio-7-price-specs-140004909.html',
#    'urlToImage': 'https://o.aolcdn.com/images/dims?resize=1200%2C630&crop=1200%2C630%2C0%2C0&quality=95&image_uri=https%3A%2F%2Fs.yimg.com%2Fos%2Fcreatr-uploaded-images%2F2021-01%2F10c6ae90-5089-11eb-9ece-be1bcf105580&client=amp-blogside-v2&signature=d39dd57407ec056e3383a0954af19873e985dd23',
#    'publishedAt': '2021-01-07T14:00:04Z',
#    'content': 'The IdeaPad 5G’s 14-inch IPS display runs at a 1,920 x 1,080 resolution and can get up to 300 nits of brightness. Keeping everything running alongside the Snapdragon 8cx is 8GB of RAM and a 512GB SSD… [+1434 chars]'},
#   {'source': {'id': 'engadget', 'name': 'Engadget'},
#    'author': 'Mariella Moon',
#    'title': 'Visa will allow select payments from Pornhub owner Mindgeek',
#    'description': 'Visa isn’t done investigating allegations of illegal activity against Pornhub, but it has apparently seen enough to start accepting payments from its parent company again. According to Reuters and CNN, the credit card company will allow payments using its car…',
#    'url': 'https://www.engadget.com/visa-payments-mindgeek-111518837.html',
#    'urlToImage': 'https://o.aolcdn.com/images/dims?resize=1200%2C630&crop=1200%2C630%2C0%2C0&quality=95&image_uri=https%3A%2F%2Fs.yimg.com%2Fos%2Fcreatr-images%2F2018-12%2F1f0a2d10-fda2-11e8-9fdb-369fe0975d9a&client=amp-blogside-v2&signature=8f80d80986f1cd33f5f3710c14ca89d1c57f4a34',
#    'publishedAt': '2020-12-24T11:15:18Z',
#    'content': '“Following a thorough review, Visa will reinstate acceptance privileges for MindGeek sites that offer professionally produced adult studio content that is subject to requirements designed to ensure c… [+1132 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Anthony Ha',
#    'title': 'Daily Crunch: Visa calls off Plaid acquisition',
#    'description': 'Regulatory action prompts Visa to back off a fintech acquisition, Uber and Moderna partner and Checkout.com is valued at $15 billion. This is your Daily Crunch for January 12, 2021. The big story: Visa calls off Plaid acquisition The deal, valued at $5.3 bill…',
#    'url': 'http://techcrunch.com/2021/01/12/daily-crunch-visa-calls-off-plaid-acquisition/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2019/02/GettyImages-913940066.jpg?w=651',
#    'publishedAt': '2021-01-12T23:14:50Z',
#    'content': 'Regulatory action prompts Visa to back off a fintech acquisition, Uber and Moderna partner and Checkout.com is valued at $15 billion. This is your Daily Crunch for January 12, 2021.\r\nThe big story: V… [+2741 chars]'},
#   {'source': {'id': 'engadget', 'name': 'Engadget'},
#    'author': 'Kris Naudus',
#    'title': 'The TCL 20 5G vs. the Motorola One 5G Ace and the Pixel 4a 5G',
#    'description': 'We don’t normally see a lot of phones at CES, but this year companies have seen fit to push up their announcements, particularly TCL and Motorola. Both have debuted new mid-range 5G phones at the show, the better to compete with Google’s existing Pixel 4a 5G …',
#    'url': 'https://www.engadget.com/tcl-20-5g-vs-motorola-one-5g-ace-pixel-4a-5g-191551741.html',
#    'urlToImage': 'https://o.aolcdn.com/images/dims?resize=1200%2C630&crop=1200%2C630%2C0%2C0&quality=95&image_uri=https%3A%2F%2Fs.yimg.com%2Fos%2Fcreatr-uploaded-images%2F2021-01%2Fc0daffb0-5440-11eb-bef9-4aca710820cc&client=amp-blogside-v2&signature=2dc534ba49c8a796a5c0c29baa8271f7443e9112',
#    'publishedAt': '2021-01-11T19:15:57Z',
#    'content': 'We don’t normally see a lot of phones at CES, but this year companies have seen fit to push up their announcements, particularly TCL and Motorola. Both have debuted new mid-range 5G phones at the sho… [+256 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Natasha Mascarenhas',
#    'title': 'The end of Plaid-Visa, and Palantir’s growing startup mafia',
#    'description': 'Hello and welcome back to\xa0Equity, TechCrunch’s venture-capital-focused podcast, where we unpack the numbers behind the headlines. This week we — Natasha and Danny and Alex and Grace — had a lot to get through, as the news volume in early 2021 has been rapid, …',
#    'url': 'http://techcrunch.com/2021/01/14/the-end-of-plaid-visa-and-palantirs-growing-startup-mafia/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2019/12/equity-podcast-2019-phone-1-4-e1578089278201.jpg?w=350',
#    'publishedAt': '2021-01-14T22:59:29Z',
#    'content': 'Hello and welcome back to\xa0Equity, TechCrunchs venture-capital-focused podcast, where we unpack the numbers behind the headlines.\r\nThis week we — Natasha and Danny and Alex and Grace — had a lot to ge… [+1003 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Alex Wilhelm',
#    'title': 'Visa will not acquire Plaid after running into regulatory wall',
#    'description': 'Visa and Plaid called off their agreement this afternoon, ending the consumer credit giant’s takeover of the data-focused fintech API startup. The deal, valued at $5.3 billion at the time of its announcement, first broke cover on January 13th, 2020, or nearly…',
#    'url': 'http://techcrunch.com/2021/01/12/visa-will-not-acquire-plaid-after-running-into-regulatory-wall/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2020/01/sarah-wardlaw-b2aKp2DfJMk-unsplash.jpg?w=598',
#    'publishedAt': '2021-01-12T21:35:07Z',
#    'content': 'Visa and Plaid called off their agreement this afternoon, ending the consumer credit giant’s takeover of the data-focused fintech API startup.\r\nThe deal, valued at $5.3 billion at the time of its ann… [+2092 chars]'},
#   {'source': {'id': None, 'name': 'Lifehacker.com'},
#    'author': 'David Murphy',
#    'title': 'Should You Preorder a $329 Nvidia GeForce RTX 3060?',
#    'description': 'Nvidia just announced its entry-level 3000-series graphics card, the $329 GeForce RTX 3060—otherwise known as the best way to get ray-tracing in your games without breaking the bank. Normally, I’d take a moment to say that you shouldn’t preorder anything with…',
#    'url': 'https://lifehacker.com/should-you-preorder-a-329-nvidia-geforce-rtx-3060-1846043773',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/rxfh5wiyfiqaneaxzhgq.png',
#    'publishedAt': '2021-01-13T15:00:00Z',
#    'content': 'Nvidia just announced its entry-level 3000-series graphics card, the $329 GeForce RTX 3060otherwise known as the best way to get ray-tracing in your games without breaking the bank. Normally, Id take… [+7427 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Manish Singh',
#    'title': 'Salesforce leads $15M investment round in Indian HR tech platform Darwinbox',
#    'description': 'Darwinbox, which operates a cloud-based human resource management platform, has raised $15 million in a new financing round as the Indian startup looks to expand beyond the country and Southeast Asian markets. The new round, a Series C, for the Hyderabad-base…',
#    'url': 'http://techcrunch.com/2021/01/18/salesforce-leads-15-million-investment-round-in-indian-hr-tech-platform-darwinbox/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2021/01/Darwinbox-OKRs-on-Mobile.jpeg?w=602',
#    'publishedAt': '2021-01-19T00:31:30Z',
#    'content': 'Darwinbox, which operates a cloud-based human resource management platform, has raised $15 million in a new financing round as the Indian startup looks to expand beyond the country and Southeast Asia… [+3046 chars]'},
#   {'source': {'id': 'engadget', 'name': 'Engadget'},
#    'author': 'Richard Lawler',
#    'title': "Verizon CEO pitches 5G as a 'platform' for services like drone delivery",
#    'description': 'As 5G connectivity rolls out across the country in fits and starts, we’re still asking whether the upgrades will make for a noticeable change in our wireless connectivity. During a CES keynote, Verizon CEO Hans Vestberg (Verizon owns Engadget’s parent company…',
#    'url': 'https://www.engadget.com/hans-vestberg-5g-ces-2021-keynote-072021484.html',
#    'urlToImage': 'https://o.aolcdn.com/images/dims?resize=1200%2C630&crop=1200%2C630%2C0%2C0&quality=95&image_uri=https%3A%2F%2Fs.yimg.com%2Fos%2Fcreatr-uploaded-images%2F2021-01%2F3d644d60-54a6-11eb-b624-dceec88049e6&client=amp-blogside-v2&signature=bdc49757a078f899688a9689f93cc1c10efe56ef',
#    'publishedAt': '2021-01-12T07:20:21Z',
#    'content': 'Other deals include Live Nation and the NFL. Verizon’s 5G UWB (the much faster kind of 5G that uses mmWave to hit up to 4 Gbps, but doesn’t have a ton of range) is being deployed at 15 Live Nation th… [+1164 chars]'},
#   {'source': {'id': None, 'name': 'Lifehacker.com'},
#    'author': 'Brendan Hesse',
#    'title': 'Why Graphics Cards Are Even More Expensive in 2021',
#    'description': 'Nvidia and AMD’s high-end graphics cards were expensive in 2020 (if you could find them), but their prices are only going up. And you can thank the government for that.Read more...',
#    'url': 'https://lifehacker.com/why-graphics-cards-are-even-more-expensive-in-2021-1846036657',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/p0v6nfx8qdz0vjbaj4cl.jpg',
#    'publishedAt': '2021-01-11T21:00:00Z',
#    'content': 'Nvidia and AMDs high-end graphics cards were expensive in 2020 (if you could find them), but their prices are only going up. And you can thank the government for that.\r\nAs of December 31, 2020, GPUs … [+2754 chars]'},
#   {'source': {'id': None, 'name': 'Lifehacker.com'},
#    'author': 'Brendan Hesse',
#    'title': "How to Watch Nvidia's 'GeForce RTX: Game On' Event Today",
#    'description': 'Later today, Nvidia’s “GeForce RTX: Game On” live event will give us our first look at the company’s latest gaming-focused hardware. (Here’s hoping any new announcements drop the price and raise the availability of its top-shelf graphics cards.)Read more...',
#    'url': 'https://lifehacker.com/how-to-watch-nvidias-geforce-rtx-game-on-event-today-1846037405',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/fqpxbw7qcx8svnntra7q.jpg',
#    'publishedAt': '2021-01-12T14:00:00Z',
#    'content': 'Later today, Nvidias GeForce RTX: Game On live event will give us our first look at the companys latest gaming-focused hardware. (Heres hoping any new announcements drop the price and raise the avail… [+1659 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Allison Johnson',
#    'title': 'The Galaxy A32 5G debuts in Europe as Samsung’s cheapest 5G phone',
#    'description': 'The Samsung Galaxy A32 5G will debut in Europe starting in February for €279 with 64GB of storage or €299 for a 128GB version.',
#    'url': 'https://www.theverge.com/2021/1/14/22231420/samsung-galaxy-a32-5g-europe-cheapest-5g-phone',
#    'urlToImage': 'https://cdn.vox-cdn.com/thumbor/xoyhNjfm9gy8sG7W1uLk27-HMk0=/0x227:2000x1274/fit-in/1200x630/cdn.vox-cdn.com/uploads/chorus_asset/file/22236080/02_galaxya32_5g_2p_lg.jpg',
#    'publishedAt': '2021-01-14T22:00:51Z',
#    'content': 'Itll go on sale in February for 279\r\nThe Galaxy A32 5G offers a 6.5-inch display and 5,000mAh battery.\r\nImage: Samsung\r\nEchoing a theme that will be repeated a lot more this year, Samsung has announc… [+1386 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Natasha Lomas',
#    'title': 'UK’s markets regulator asks for views on Nvidia-Arm',
#    'description': 'The UK’s competition and markets regulator is seeking views on Nvidia’s takeover of Arm Holdings as it prepares to kick off formal oversight of potential competitive impacts of the deal. The US-based chipmaker’s $40BN purchase of the UK-based chip designer, a…',
#    'url': 'http://techcrunch.com/2021/01/06/uks-markets-regulator-asks-for-views-on-nvidia-arm/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2019/01/ces-2019-0028.jpg?w=600',
#    'publishedAt': '2021-01-06T15:33:24Z',
#    'content': 'The UK’s competition and markets regulator is seeking views on Nvidia’s takeover of Arm Holdings as it prepares to kick off formal oversight of potential competitive impacts of the deal.\r\nThe US-base… [+2865 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Walter Thompson',
#    'title': 'Dear Sophie: What’s the new minimum salary required for H-1B visa applicants?',
#    'description': 'I hear the random H-1B lottery will be replaced with a new system that selects H-1B candidates based on their salaries. How will this new process work?',
#    'url': 'http://techcrunch.com/2021/01/13/dear-sophie-whats-up-with-h-1b-pay-to-play/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2020/06/SA-at-TC.jpg?w=642',
#    'publishedAt': '2021-01-13T15:30:28Z',
#    'content': 'More posts by this contributor\r\nHere’s another edition of Dear Sophie, the advice column that answers immigration-related questions about working at technology companies.\r\nYour questions are vital to… [+2840 chars]'},
#   {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#    'author': 'https://www.facebook.com/bbcnews',
#    'title': 'The Hong Kong migrants fleeing to start new lives in the UK',
#    'description': 'A new visa will give 5.4m Hong Kong residents the right to resettle in Britain. How many will leave?',
#    'url': 'https://www.bbc.co.uk/news/world-asia-china-55357495',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/E52F/production/_116217685_andyliandfamily-002.jpg',
#    'publishedAt': '2021-01-19T00:15:51Z',
#    'content': "By Michael BristowBBC News\r\nimage captionResidents of the UK's former colony believe China is undermining Hong Kong's rights and freedoms\r\nThe UK will introduce a new visa at the end of January that … [+6004 chars]"},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Danny Crichton',
#    'title': '2021 will be a calmer year for semiconductors and chips (except for Intel)',
#    'description': 'If ever there was a typically quiet tech industry that seemed to drive massive headlines this year, it was semiconductors. From record-setting M&A purchases to prodigious venture capital financing, the decline of major players and huge international trade fig…',
#    'url': 'http://techcrunch.com/2020/12/28/semiconductors-in-2021/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2020/12/GettyImages-184912447.jpg?w=605',
#    'publishedAt': '2020-12-28T17:01:34Z',
#    'content': 'If ever there was a typically quiet tech industry that seemed to drive massive headlines this year, it was semiconductors. From record-setting M&amp;A purchases to prodigious venture capital financin… [+5782 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Danny Crichton',
#    'title': 'The deplatforming of a president',
#    'description': 'After years of placid admonishments, the tech world came out in force against President Trump this past week following the violent assault of the U.S. Capitol building in Washington D.C. on Wednesday. From Twitter to PayPal, more than a dozen companies have p…',
#    'url': 'http://techcrunch.com/2021/01/09/the-deplatforming-of-a-president/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2021/01/GettyImages-1155448140.jpg?w=463',
#    'publishedAt': '2021-01-09T16:46:17Z',
#    'content': 'After years of placid admonishments, the tech world came out in force against President Trump this past week following the violent assault of the U.S. Capitol building in Washington D.C. on Wednesday… [+12117 chars]'},
#   {'source': {'id': None, 'name': 'Android Central'},
#    'author': 'Babu Mohan',
#    'title': "NVIDIA's GeForce NOW is expanding to three new countries",
#    'description': "NVIDIA's GeForce NOW Alliance continues to grow.\n\n\n\nWhat you need to know\n\n\nNVIDIA's GeForce NOW game streaming service will soon be available in three new markets.\nThe cloud gaming service is coming to Australia, Turkey, and Saudi Arabia.\nAustralia's Pentane…",
#    'url': 'https://www.androidcentral.com/nvidias-geforce-now-alliance-expanding-three-new-countries',
#    'urlToImage': 'https://www.androidcentral.com/sites/androidcentral.com/files/styles/large/public/field/image/2017/01/geforce-now-949c.jpg',
#    'publishedAt': '2021-01-21T14:00:02Z',
#    'content': 'NVIDIA today announced that its GeForce NOW game streaming service is expanding to Australia, Turkey, and Saudi Arabia. To help bring cloud gaming to more gamers, NVIDIA has partnered with leading te… [+1426 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Romain Dillet',
#    'title': 'Gemini is launching a credit card with bitcoin rewards',
#    'description': 'Cryptocurrency exchange company Gemini is acquiring Blockrize and announcing a new product today based on Blockrize’s work. Later this year, the company is launching a credit card that works like a regular credit card — but you earn bitcoin rewards based on y…',
#    'url': 'http://techcrunch.com/2021/01/14/gemini-is-launching-a-credit-card-with-bitcoin-rewards/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2021/01/Tyler_Cameron-Winklevoss-2-1.jpg?w=500',
#    'publishedAt': '2021-01-14T12:00:50Z',
#    'content': 'Cryptocurrency exchange company Gemini is acquiring Blockrize and announcing a new product today based on Blockrizes work. Later this year, the company is launching a credit card that works like a re… [+1479 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Belle Lin',
#    'title': "The inventor of 5G predicts the technology will doom Silicon Valley and catapult China. Here's the roadmap Amazon, Microsoft, and Google must follow to follow to stay ahead. (GOOG, AMZN, MSFT)",
#    'description': "Summary List PlacementErdal Arikan, a Turkish professor and scientist, held a low profile until Huawei — China's leading 5G equipment manufacturer and the world's second largest seller of smartphones — elevated his work out of obscurity and made it the underl…",
#    'url': 'https://www.businessinsider.com/china-lead-5g-experts-say-big-tech-wins-on-software-2021-1',
#    'urlToImage': 'https://i.insider.com/600b430f7e47190011cb8d68?width=1200&format=jpeg',
#    'publishedAt': '2021-01-23T14:03:00Z',
#    'content': "Erdal Arikan, a Turkish professor and scientist, held a low profile until Huawei — China's leading 5G equipment manufacturer and the world's second largest seller of smartphones — elevated his work o… [+11685 chars]"}]}

# %%
# Fetch the XLU - Utilities Sector news articles
utility_headlines = newsapi.get_everything(q="AmericanUtilitiesSector OR NextEra OR NEE OR DUK OR DukeEnergy OR GreenEnergy OR SO OR DominionEnergy OR AmericanElectricPower OR Visa OR Exelon OR SempraEnergy OR XcelEnergy OR EversourceEnergy OR PublicServiceEnterprise OR ConEdison",
                                           language="en",
                                           sort_by="relevancy")
utility_headlines
# Out:
# {'status': 'ok',
#  'totalResults': 395762,
#  'articles': [{'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Natasha Mascarenhas',
#    'title': 'The end of Plaid-Visa, and Palantir’s growing startup mafia',
#    'description': 'Hello and welcome back to\xa0Equity, TechCrunch’s venture-capital-focused podcast, where we unpack the numbers behind the headlines. This week we — Natasha and Danny and Alex and Grace — had a lot to get through, as the news volume in early 2021 has been rapid, …',
#    'url': 'http://techcrunch.com/2021/01/14/the-end-of-plaid-visa-and-palantirs-growing-startup-mafia/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2019/12/equity-podcast-2019-phone-1-4-e1578089278201.jpg?w=350',
#    'publishedAt': '2021-01-14T22:59:29Z',
#    'content': 'Hello and welcome back to\xa0Equity, TechCrunchs venture-capital-focused podcast, where we unpack the numbers behind the headlines.\r\nThis week we — Natasha and Danny and Alex and Grace — had a lot to ge… [+1003 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Alex Wilhelm',
#    'title': 'Visa will not acquire Plaid after running into regulatory wall',
#    'description': 'Visa and Plaid called off their agreement this afternoon, ending the consumer credit giant’s takeover of the data-focused fintech API startup. The deal, valued at $5.3 billion at the time of its announcement, first broke cover on January 13th, 2020, or nearly…',
#    'url': 'http://techcrunch.com/2021/01/12/visa-will-not-acquire-plaid-after-running-into-regulatory-wall/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2020/01/sarah-wardlaw-b2aKp2DfJMk-unsplash.jpg?w=598',
#    'publishedAt': '2021-01-12T21:35:07Z',
#    'content': 'Visa and Plaid called off their agreement this afternoon, ending the consumer credit giant’s takeover of the data-focused fintech API startup.\r\nThe deal, valued at $5.3 billion at the time of its ann… [+2092 chars]'},
#   {'source': {'id': 'engadget', 'name': 'Engadget'},
#    'author': 'Mariella Moon',
#    'title': 'Visa will allow select payments from Pornhub owner Mindgeek',
#    'description': 'Visa isn’t done investigating allegations of illegal activity against Pornhub, but it has apparently seen enough to start accepting payments from its parent company again. According to Reuters and CNN, the credit card company will allow payments using its car…',
#    'url': 'https://www.engadget.com/visa-payments-mindgeek-111518837.html',
#    'urlToImage': 'https://o.aolcdn.com/images/dims?resize=1200%2C630&crop=1200%2C630%2C0%2C0&quality=95&image_uri=https%3A%2F%2Fs.yimg.com%2Fos%2Fcreatr-images%2F2018-12%2F1f0a2d10-fda2-11e8-9fdb-369fe0975d9a&client=amp-blogside-v2&signature=8f80d80986f1cd33f5f3710c14ca89d1c57f4a34',
#    'publishedAt': '2020-12-24T11:15:18Z',
#    'content': '“Following a thorough review, Visa will reinstate acceptance privileges for MindGeek sites that offer professionally produced adult studio content that is subject to requirements designed to ensure c… [+1132 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Anthony Ha',
#    'title': 'Daily Crunch: Visa calls off Plaid acquisition',
#    'description': 'Regulatory action prompts Visa to back off a fintech acquisition, Uber and Moderna partner and Checkout.com is valued at $15 billion. This is your Daily Crunch for January 12, 2021. The big story: Visa calls off Plaid acquisition The deal, valued at $5.3 bill…',
#    'url': 'http://techcrunch.com/2021/01/12/daily-crunch-visa-calls-off-plaid-acquisition/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2019/02/GettyImages-913940066.jpg?w=651',
#    'publishedAt': '2021-01-12T23:14:50Z',
#    'content': 'Regulatory action prompts Visa to back off a fintech acquisition, Uber and Moderna partner and Checkout.com is valued at $15 billion. This is your Daily Crunch for January 12, 2021.\r\nThe big story: V… [+2741 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Walter Thompson',
#    'title': 'Dear Sophie: What’s the new minimum salary required for H-1B visa applicants?',
#    'description': 'I hear the random H-1B lottery will be replaced with a new system that selects H-1B candidates based on their salaries. How will this new process work?',
#    'url': 'http://techcrunch.com/2021/01/13/dear-sophie-whats-up-with-h-1b-pay-to-play/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2020/06/SA-at-TC.jpg?w=642',
#    'publishedAt': '2021-01-13T15:30:28Z',
#    'content': 'More posts by this contributor\r\nHere’s another edition of Dear Sophie, the advice column that answers immigration-related questions about working at technology companies.\r\nYour questions are vital to… [+2840 chars]'},
#   {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#    'author': 'https://www.facebook.com/bbcnews',
#    'title': 'The Hong Kong migrants fleeing to start new lives in the UK',
#    'description': 'A new visa will give 5.4m Hong Kong residents the right to resettle in Britain. How many will leave?',
#    'url': 'https://www.bbc.co.uk/news/world-asia-china-55357495',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/E52F/production/_116217685_andyliandfamily-002.jpg',
#    'publishedAt': '2021-01-19T00:15:51Z',
#    'content': "By Michael BristowBBC News\r\nimage captionResidents of the UK's former colony believe China is undermining Hong Kong's rights and freedoms\r\nThe UK will introduce a new visa at the end of January that … [+6004 chars]"},
#   {'source': {'id': None, 'name': 'Lifehacker.com'},
#    'author': 'Sam Blum',
#    'title': 'Why Are My Feet Always So Cold?',
#    'description': 'I wear fuzzy slippers around the house, not because I think myself fancy, or even because prefer the feeling of soft, fuzzy fur to bare feet. I do this because my feet are always—and I mean always—freezing. In the winter, I stuff toe warmers into my thickest …',
#    'url': 'https://lifehacker.com/why-are-my-feet-always-so-cold-1846099559',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/e36u8bvr850fq4g48vjo.jpg',
#    'publishedAt': '2021-01-21T16:15:00Z',
#    'content': 'I wear fuzzy slippers around the house, not because I think myself fancy, or even because prefer the feeling of soft, fuzzy fur to bare feet. I do this because my feet are alwaysand I mean alwaysfree… [+4791 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Danny Crichton',
#    'title': 'Will startup valuations change given rising antitrust concerns?',
#    'description': 'The United States has, over the past few decades, been extremely lenient on antitrust enforcement, rarely blocking deals, even with overseas competitors. Yet, there have been inklings that things are changing. Yesterday, we learned that Visa and Plaid called …',
#    'url': 'http://techcrunch.com/2021/01/13/will-startup-valuations-change-given-rising-antitrust-concerns/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2019/10/GettyImages-926051128.jpg?w=588',
#    'publishedAt': '2021-01-13T16:56:36Z',
#    'content': 'The United States has, over the past few decades, been extremely lenient on antitrust enforcement, rarely blocking deals, even with overseas competitors. Yet, there have been inklings that things are… [+939 chars]'},
#   {'source': {'id': None, 'name': 'Lifehacker.com'},
#    'author': 'Sam Blum',
#    'title': 'So You Want to Learn to Play the Drums',
#    'description': 'So you want to learn to play the drums. Thrash the skins. Hit some wooden circles with sticks in the pursuit of that sweet, sweet rhythm. In this endeavor I salute you, especially if you’re a kid living at home with your parents (they will learn to deal with …',
#    'url': 'https://lifehacker.com/so-you-want-to-learn-to-play-the-drums-1846112277',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/nyhv0zvilxfczezb321x.jpg',
#    'publishedAt': '2021-01-22T22:30:00Z',
#    'content': 'So you want to learn to play the drums. Thrash the skins. Hit some wooden circles with sticks in the pursuit of that sweet, sweet rhythm. In this endeavor I salute you, especially if youre a kid livi… [+4327 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Romain Dillet',
#    'title': 'Gemini is launching a credit card with bitcoin rewards',
#    'description': 'Cryptocurrency exchange company Gemini is acquiring Blockrize and announcing a new product today based on Blockrize’s work. Later this year, the company is launching a credit card that works like a regular credit card — but you earn bitcoin rewards based on y…',
#    'url': 'http://techcrunch.com/2021/01/14/gemini-is-launching-a-credit-card-with-bitcoin-rewards/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2021/01/Tyler_Cameron-Winklevoss-2-1.jpg?w=500',
#    'publishedAt': '2021-01-14T12:00:50Z',
#    'content': 'Cryptocurrency exchange company Gemini is acquiring Blockrize and announcing a new product today based on Blockrizes work. Later this year, the company is launching a credit card that works like a re… [+1479 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Daniel Wiessner',
#    'title': '4th Circuit revives claim over USCIS delays in processing U visa applications - Reuters',
#    'description': 'The 4th U.S. Circuit Court of Appeals on Thursday revived claims that U.S. Citizenship and Immigration Services has unreasonably delayed in placing five applicants for U visas on waiting lists so they can qualify for permits allowing them to work legally in t…',
#    'url': 'https://www.reuters.com/article/immigration-uvisas/4th-circuit-revives-claim-over-uscis-delays-in-processing-u-visa-applications-idUSL1N2JP34P',
#    'urlToImage': 'https://s1.reutersmedia.net/resources_v2/images/rcom-default.png?w=800',
#    'publishedAt': '2021-01-14T22:15:00Z',
#    'content': 'The 4th U.S. Circuit Court of Appeals on Thursday revived claims that U.S. Citizenship and Immigration Services has unreasonably delayed in placing five applicants for U visas on waiting lists so the… [+486 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Brian Kahn on Earther, shared by Andrew Couts to Gizmodo',
#    'title': "2020 Could've Been So Much Worse",
#    'description': 'A week into 2021, the lesson is already clear that things can get so, so much worse. As if to underscore that, the National Oceanic and Atmospheric Administration released a report on Friday looking back on 2020, which shows that the U.S. saw a record number …',
#    'url': 'https://earther.gizmodo.com/2020-couldve-been-so-much-worse-1846033758',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/iff2e2xz5kgiwyf1xueh.jpg',
#    'publishedAt': '2021-01-11T16:16:00Z',
#    'content': 'A week into 2021, the lesson is already clear that things can get so, so much worse. As if to underscore that, the National Oceanic and Atmospheric Administration released a report on Friday looking … [+2687 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'Visa temporarily suspends all political donations - Reuters',
#    'description': 'Visa Inc said on Tuesday its political action committee had temporarily suspended all donations last week as it reviews its candidate contribution guidelines.',
#    'url': 'https://www.reuters.com/article/us-usa-election-corporate-visa/visa-temporarily-suspends-all-political-donations-idUSKBN29H2D4',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210112&t=2&i=1547515979&r=LYNXMPEH0B18F&w=800',
#    'publishedAt': '2021-01-12T16:54:00Z',
#    'content': 'By Reuters Staff\r\nFILE PHOTO: A Visa credit card is seen on a computer keyboard in this picture illustration taken September 6, 2017. REUTERS/Philippe Wojazer/Illustration\r\n(Reuters) - Visa Inc said … [+663 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'Visa temporarily suspends all political donations - Reuters',
#    'description': 'Visa Inc said on Tuesday its political action committee had temporarily suspended all donations last week as it reviews its candidate contribution guidelines.',
#    'url': 'https://www.reuters.com/article/us-usa-election-corporate-visa/visa-temporarily-suspends-all-political-donations-idUSKBN29I2KT',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210112&t=2&i=1547515979&r=LYNXMPEH0B18F&w=800',
#    'publishedAt': '2021-01-13T17:47:00Z',
#    'content': 'By Reuters Staff\r\nFILE PHOTO: A Visa credit card is seen on a computer keyboard in this picture illustration taken September 6, 2017. REUTERS/Philippe Wojazer/Illustration\r\n(Reuters) - Visa Inc said … [+712 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'Visa temporarily suspends all political donations - Reuters',
#    'description': 'Visa Inc said on Tuesday its political action committee had temporarily suspended all donations last week as it reviews its candidate contribution guidelines.',
#    'url': 'https://www.reuters.com/article/usa-election-corporate-visa/visa-temporarily-suspends-all-political-donations-idUSL4N2JN3D0',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210112&t=2&i=1547515979&r=LYNXMPEH0B18F&w=800',
#    'publishedAt': '2021-01-12T16:54:00Z',
#    'content': 'By Reuters Staff\r\nFILE PHOTO: A Visa credit card is seen on a computer keyboard in this picture illustration taken September 6, 2017. REUTERS/Philippe Wojazer/Illustration\r\n(Reuters) - Visa Inc said … [+663 chars]'},
#   {'source': {'id': None, 'name': 'Lifehacker.com'},
#    'author': 'Elizabeth Yuko',
#    'title': "How to Improve Your Balance So You Don't Fall This Winter",
#    'description': 'Though it’s easy to label someone who frequently slips, trips, falls and/or knocks into things as being “clumsy,” there is usually more to the story than that. While it’s possible that their main problem is not looking where they’re going or paying attention …',
#    'url': 'https://lifehacker.com/how-to-improve-your-balance-so-you-dont-fall-this-winte-1845959089',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/babhge6mqsg1senxefgj.jpg',
#    'publishedAt': '2020-12-31T14:30:00Z',
#    'content': 'Though its easy to label someone who frequently slips, trips, falls and/or knocks into things as being clumsy, there is usually more to the story than that. While its possible that their main problem… [+2578 chars]'},
#   {'source': {'id': None, 'name': 'Lifehacker.com'},
#    'author': 'Melanie Pinola',
#    'title': 'How I Learned to Stop Being So Jealous and Finally Get on with My Life',
#    'description': 'Jealousy and envy are two of the most common—yet negative and useless—emotions many of us have. For a long time, I let both of these destructive feelings overwhelm and poison me. Here’s how I finally gained control over them.Read more...',
#    'url': 'https://lifehacker.com/how-i-learned-to-stop-being-so-jealous-and-finally-get-1529920256',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/k0a7cf3rk4ohthfgftev.jpg',
#    'publishedAt': '2020-12-29T21:30:00Z',
#    'content': 'Jealousy and envy are two of the most commonyet negative and uselessemotions many of us have. For a long time, I let both of these destructive feelings overwhelm and poison me. Heres how I finally ga… [+5984 chars]'},
#   {'source': {'id': None, 'name': 'Lifehacker.com'},
#    'author': 'Stephen Johnson',
#    'title': "The Out-of-Touch Adults' Guide To Kid Culture: So Many Internet Controversies",
#    'description': 'This week’s look at kidz’ pop-culture features an overload of useless web-celebs, a fight over Wonder Woman, and even a talking dog. So dig in—I promise I won’t mention COVID-19 at all! (Except there, where I just did.) Thank Odin the holidays are over and ou…',
#    'url': 'https://lifehacker.com/the-out-of-touch-adults-guide-to-kid-culture-so-many-i-1845957074',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/vb8fmnnuvvjexfhf2v50.jpg',
#    'publishedAt': '2020-12-29T16:00:00Z',
#    'content': 'This weeks look at kidz pop-culture features an overload of useless web-celebs, a fight over Wonder Woman, and even a talking dog. So dig inI promise I wont mention COVID-19 at all! (Except there, wh… [+4981 chars]'},
#   {'source': {'id': None, 'name': 'Lifehacker.com'},
#    'author': 'David Murphy',
#    'title': 'Declutter Your Devices to Reduce Security Risks',
#    'description': 'When I think about “rebooting” my digital life, the first thing that comes to mind are the many, many browser tabs that I keep telling myself I’ll organize someday. Then I think about my cluttered phone, too—so many apps, so little time. Then my thoughts go b…',
#    'url': 'https://lifehacker.com/declutter-your-devices-to-reduce-security-risks-1845991606',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/fqds3gnkogaasvhhgnge.jpg',
#    'publishedAt': '2021-01-05T20:00:00Z',
#    'content': 'When I think about rebooting my digital life, the first thing that comes to mind are the many, many browser tabs that I keep telling myself Ill organize someday. Then I think about my cluttered phone… [+6288 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'UAE, Israel postpone visa exemption deal over COVID-19 worries - Reuters',
#    'description': 'The United Arab Emirates has postponed the implementation of a visa-exemption agreement with Israel after Israel required anyone entering from the Gulf state to be quarantined as a COVID-19 precaution, Israeli officials said on Monday.',
#    'url': 'https://www.reuters.com/article/health-coronavirus-israel-emirates/uae-israel-postpone-visa-exemption-deal-over-covid-19-worries-idUSL8N2JT34G',
#    'urlToImage': 'https://s1.reutersmedia.net/resources_v2/images/rcom-default.png?w=800',
#    'publishedAt': '2021-01-18T14:30:00Z',
#    'content': 'By Reuters Staff\r\nJERUSALEM (Reuters) - The United Arab Emirates has postponed the implementation of a visa-exemption agreement with Israel after Israel required anyone entering from the Gulf state t… [+1287 chars]'}]}

# %%
# Fetch the XLI - Industrial Sector news articles
indust_headlines = newsapi.get_everything(q="(AmericanIndustrialSector OR +HON OR +HoneywellInternational OR +UNP OR +UnionPacificCorp OR +UPS OR +UnitedPostalService OR +Boeing OR +Raytheon OR +RTX OR +MMM OR +3M OR +CaterpillarInc OR +GE OR +GeneralElectric OR +LMT OR +LockheedMartin OR +DE OR +JohnDeere)",
                                           language="en",
                                           sort_by="relevancy")
indust_headlines
# Out:
# {'status': 'ok',
#  'totalResults': 59188,
#  'articles': [{'source': {'id': 'engadget', 'name': 'Engadget'},
#    'author': 'Igor Bonifacic',
#    'title': 'Amazon buys planes for the first time to expand its cargo air fleet',
#    'description': 'Back in 2016, Amazon’s cargo air fleet (then known as Prime Air) consisted of 11 jets. By the end of 2022, the company told Bloomberg it expects to have more than 85 planes shuttling products across the US and other countries thanks to its recent acquisition …',
#    'url': 'https://www.engadget.com/amazon-buys-11-boeing-767-300-planes-193659460.html',
#    'urlToImage': 'https://o.aolcdn.com/images/dims?resize=1200%2C630&crop=1200%2C630%2C0%2C0&quality=95&image_uri=https%3A%2F%2Fs.yimg.com%2Fos%2Fcreatr-uploaded-images%2F2021-01%2F182e37f0-4f8c-11eb-9cae-575053f67417&client=amp-blogside-v2&signature=91df92cd63bcbb2eacad1eacc8326f303840924d',
#    'publishedAt': '2021-01-05T19:36:59Z',
#    'content': 'Back in 2016, Amazon’s cargo air fleet (then known as Prime Air) consisted of 11 jets. By the end of 2022, the company told Bloomberg it expects to have more than 85 planes shuttling products across … [+650 chars]'},
#   {'source': {'id': None, 'name': 'Lifehacker.com'},
#    'author': 'Brendan Hesse',
#    'title': 'Use DLSS to Make Your PC Game Run Better',
#    'description': 'Ray Tracing and 4K are the most-talked-about capabilities of Nvidia’s GeForce RTX graphics cards. The DLSS feature these GPUs can use doesn’t get as much buzz, but it’s just as impressive—especially given the magic it can work on frame rates for those playing…',
#    'url': 'https://lifehacker.com/use-dlss-to-make-your-pc-game-run-better-1846058571',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/eptqirpn36bzldrrwdb0.jpg',
#    'publishedAt': '2021-01-14T17:00:00Z',
#    'content': 'Ray Tracing and 4K are the most-talked-about capabilities of Nvidias GeForce RTX graphics cards. The DLSS feature these GPUs can use doesnt get as much buzz, but its just as impressiveespecially give… [+3466 chars]'},
#   {'source': {'id': None, 'name': 'Lifehacker.com'},
#    'author': 'David Murphy',
#    'title': 'Should You Preorder a $329 Nvidia GeForce RTX 3060?',
#    'description': 'Nvidia just announced its entry-level 3000-series graphics card, the $329 GeForce RTX 3060—otherwise known as the best way to get ray-tracing in your games without breaking the bank. Normally, I’d take a moment to say that you shouldn’t preorder anything with…',
#    'url': 'https://lifehacker.com/should-you-preorder-a-329-nvidia-geforce-rtx-3060-1846043773',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/rxfh5wiyfiqaneaxzhgq.png',
#    'publishedAt': '2021-01-13T15:00:00Z',
#    'content': 'Nvidia just announced its entry-level 3000-series graphics card, the $329 GeForce RTX 3060otherwise known as the best way to get ray-tracing in your games without breaking the bank. Normally, Id take… [+7427 chars]'},
#   {'source': {'id': None, 'name': 'Lifehacker.com'},
#    'author': 'Brendan Hesse',
#    'title': "How to Watch Nvidia's 'GeForce RTX: Game On' Event Today",
#    'description': 'Later today, Nvidia’s “GeForce RTX: Game On” live event will give us our first look at the company’s latest gaming-focused hardware. (Here’s hoping any new announcements drop the price and raise the availability of its top-shelf graphics cards.)Read more...',
#    'url': 'https://lifehacker.com/how-to-watch-nvidias-geforce-rtx-game-on-event-today-1846037405',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/fqpxbw7qcx8svnntra7q.jpg',
#    'publishedAt': '2021-01-12T14:00:00Z',
#    'content': 'Later today, Nvidias GeForce RTX: Game On live event will give us our first look at the companys latest gaming-focused hardware. (Heres hoping any new announcements drop the price and raise the avail… [+1659 chars]'},
#   {'source': {'id': 'engadget', 'name': 'Engadget'},
#    'author': 'Jon Fingas',
#    'title': "GE's smart home brand expands beyond lighting with a security camera",
#    'description': 'GE sold its lighting business to smart home veteran Savant this spring, and that’s about to have a significant impact on the devices you can buy. The newly owned GE Lighting is ditching the slightly awkward C by GE branding in favor of the Cync name in the mo…',
#    'url': 'https://www.engadget.com/c-by-ge-cync-security-camera-thermostat-130039292.html',
#    'urlToImage': 'https://o.aolcdn.com/images/dims?resize=1200%2C630&crop=1200%2C630%2C0%2C0&quality=95&image_uri=https%3A%2F%2Fs.yimg.com%2Fos%2Fcreatr-uploaded-images%2F2020-12%2F895874e0-4aaf-11eb-b2f9-e4b07c4a6b3d&client=amp-blogside-v2&signature=5961600c41102a684215f948068337b8f9527803',
#    'publishedAt': '2021-01-05T13:00:39Z',
#    'content': 'A thermostat is also in the works, GE Lighting said, although it didn’t provide further details.\r\nThe first product is more modest. The Cync Outdoor Smart Plug lets you remotely control two outlets (… [+868 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Brian Heater',
#    'title': 'C by GE gets rebranded under new ownership, expands beyond lighting',
#    'description': 'There’s a decent chance you missed the news back in May — there was, after all, a lot going on at the time. General Electric sold off its more than 100-year-old GE Lighting division to smart home company Savant. Today, the division’s new owner is announcing a…',
#    'url': 'http://techcrunch.com/2021/01/05/c-by-ge-gets-rebranded-under-new-ownership-readies-non-lighting-products/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2021/01/gw9cJTvg.jpeg?w=600',
#    'publishedAt': '2021-01-05T13:00:24Z',
#    'content': 'Theres a decent chance you missed the news back in May — there was, after all, a lot going on at the time. General Electric sold off its more than 100-year-old GE Lighting division to smart home comp… [+1345 chars]'},
#   {'source': {'id': None, 'name': 'New York Times'},
#    'author': 'Vanessa Friedman, Elizabeth Paton, Jessica Testa and Guy Trebay',
#    'title': 'The Ups and Downs of Fashion in 2020',
#    'description': 'What happened in 2020, when everyone’s life (and wardrobe) was turned upside down.',
#    'url': 'https://www.nytimes.com/2020/12/23/style/the-ups-and-downs-of-fashion-in-2020.html',
#    'urlToImage': 'https://static01.nyt.com/images/2020/12/23/fashion/23UP-DOWN-FASHION_ART/23UP-DOWN-FASHION_ART-facebookJumbo.jpg',
#    'publishedAt': '2020-12-23T10:00:14Z',
#    'content': 'For a brief time, Ms. Morrison was so determined to flaunt the style she spent a lifetime cultivating that she made a point of dressing in complete looks to walk the dog, for school visits or even to… [+2367 chars]'},
#   {'source': {'id': None, 'name': 'New York Times'},
#    'author': 'Niraj Chokshi',
#    'title': 'Boeing 737 Max to Resume Flying U.S. Passengers on Tuesday',
#    'description': 'American Airlines will use the plane, which has been grounded for nearly two years, on a flight from Miami to New York.',
#    'url': 'https://www.nytimes.com/2020/12/29/business/boeing-737-max-return.html',
#    'urlToImage': 'https://static01.nyt.com/images/2020/12/29/us/29boeing/29boeing-facebookJumbo.jpg',
#    'publishedAt': '2020-12-29T12:00:07Z',
#    'content': 'The F.A.A. has since been joined by regulators in Brazil. Canadian and European aviation officials are expected to follow with approvals within weeks.\r\nThe families of those killed aboard the two fat… [+1288 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'US State Department approves $4.2 billion in potential arms sales to Kuwait -Pentagon - Reuters',
#    'description': 'US State Department approves $4.2 billion in potential arms sales to Kuwait -Pentagon\xa0\xa0Reuters',
#    'url': 'https://www.reuters.com/article/us-usa-kuwait-arms-idUSKBN2931ZQ',
#    'urlToImage': None,
#    'publishedAt': '2020-12-29T21:13:00Z',
#    'content': 'FILE PHOTO: The Pentagon building is seen in Arlington, Virginia, U.S. October 9, 2020. REUTERS/Carlos Barria\r\nAerospace and Defense\r\nMike Stone\r\nWASHINGTON (Reuters) - The U.S. State Department has … [+1150 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Joanna Nelius',
#    'title': "Nvidia's Ray Tracing 30-Series GPUs Are Coming to Laptops",
#    'description': 'Like clockwork, Nvidia announced this morning that its wildly fast discrete desktop graphics will be coming to laptops everywhere in the months ahead. This probably surprised no one, as Nvidia always has the same GPUs on laptops, but if the popular reception …',
#    'url': 'https://gizmodo.com/nvidias-ray-tracing-30-series-gpus-are-coming-to-laptop-1846042374',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/rysaiu9ad4meqediq7pd.png',
#    'publishedAt': '2021-01-12T17:41:00Z',
#    'content': 'Like clockwork, Nvidia announced this morning that its wildly fast discrete desktop graphics will be coming to laptops everywhere in the months ahead. This probably surprised no one, as Nvidia always… [+1261 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'George Dvorsky',
#    'title': 'NASA Completes ‘Wet Dress Rehearsal’ of Its Most Powerful Rocket',
#    'description': 'Engineers from NASA and Boeing have added cryogenic propellants to the core stage of the Space Launch System (SLS), reaching a major milestone in the development of this advanced rocket.Read more...',
#    'url': 'https://gizmodo.com/nasa-completes-wet-dress-rehearsal-of-its-most-powerf-1845933206',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/q60rbkpkkzp1ydxpuk2w.jpg',
#    'publishedAt': '2020-12-22T16:05:00Z',
#    'content': 'Engineers from NASA and Boeing have added cryogenic propellants to the core stage of the Space Launch System (SLS), reaching a major milestone in the development of this advanced rocket.\r\nThats seven… [+2496 chars]'},
#   {'source': {'id': 'engadget', 'name': 'Engadget'},
#    'author': 'Devindra Hardawar',
#    'title': 'The future of gaming laptops with ASUS ROG',
#    'description': 'Now that we’ve got new NVIDIA RTX 30-series GPUs and AMD’s Ryzen 5000 chips on the way, it’s a great time to be in the market for a gaming laptop. To see where ASUS ROG is headed, we chatted with Jeff Kampman, part of the company’s technical marketing team. H…',
#    'url': 'https://www.engadget.com/asus-rog-future-gaming-laptops-225017333.html',
#    'urlToImage': 'https://o.aolcdn.com/images/dims?resize=1200%2C630&crop=1200%2C630%2C0%2C0&quality=95&image_uri=https%3A%2F%2Fs.yimg.com%2Fos%2Fcreatr-uploaded-images%2F2021-01%2F42372a60-5523-11eb-bff5-f6dfc0c3461b&client=amp-blogside-v2&signature=bf5814bbc1e71285cd95ca48067f3f7d085b6314',
#    'publishedAt': '2021-01-12T22:50:17Z',
#    'content': 'Now that weve got new NVIDIA RTX 30-series GPUs and AMDs Ryzen 5000 chips on the way, its a great time to be in the market for a gaming laptop. To see where ASUS ROG is headed, we chatted with Jeff K… [+211 chars]'},
#   {'source': {'id': None, 'name': 'CNET'},
#    'author': 'Ry Crist',
#    'title': "Cya, C by GE: GE Lighting's growing smart home lineup is now called Cync - CNET",
#    'description': 'For 2021, GE Lighting is revamping its smart home lineup, complete with a brand-new app and new gadgets, too.',
#    'url': 'https://www.cnet.com/news/cya-c-by-ge-ge-lightings-growing-smart-home-lineup-is-now-called-cync/',
#    'urlToImage': 'https://cnet2.cbsistatic.com/img/--mKDLzh6JACPTaR3KIvzD8QwsE=/1200x630/2021/01/04/149c665c-2360-48cd-bb60-cc0d83c96323/cync-indoor-smart-camera-lifestyle-1.jpg',
#    'publishedAt': '2021-01-05T13:00:00Z',
#    'content': "C by GE is now 'Cync' -- and there's an indoor camera coming to the lineup in May.\r\nGE Lighting\r\nThis story is part of CES, where our editors will bring you the latest news and the hottest gadgets of… [+3603 chars]"},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Trevor Hunnicutt',
#    'title': "Biden's Defense nominee could get $1.7 million as he leaves Raytheon - Reuters",
#    'description': "President-elect Joe Biden's choice for U.S. defense secretary, retired General Lloyd Austin, stands to collect as much as $1.7 million connected with leaving Raytheon Technologies Corp, an ethics disclosure showed on Sunday.",
#    'url': 'https://www.reuters.com/article/usa-biden-defense/bidens-defense-nominee-could-get-17-million-as-he-leaves-raytheon-idUSL1N2JL075',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210110&t=2&i=1547278991&r=LYNXMPEH090BH&w=800',
#    'publishedAt': '2021-01-10T14:44:00Z',
#    'content': 'WILMINGTON, Del. (Reuters) - President-elect Joe Bidens choice for U.S. defense secretary, retired General Lloyd Austin, stands to collect as much as $1.7 million connected with leaving Raytheon Tech… [+1804 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Trevor Hunnicutt',
#    'title': "Biden's Defense nominee could get $1.7 million as he leaves Raytheon - Reuters",
#    'description': "President-elect Joe Biden's choice for U.S. defense secretary, retired General Lloyd Austin, stands to collect as much as $1.7 million connected with leaving Raytheon Technologies Corp, an ethics disclosure showed on Sunday.",
#    'url': 'https://www.reuters.com/article/us-usa-biden-defense/bidens-defense-nominee-could-get-1-7-million-as-he-leaves-raytheon-idUSKBN29F0EO',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210110&t=2&i=1547278991&r=LYNXMPEH090BH&w=800',
#    'publishedAt': '2021-01-10T14:44:00Z',
#    'content': 'WILMINGTON, Del. (Reuters) - President-elect Joe Bidens choice for U.S. defense secretary, retired General Lloyd Austin, stands to collect as much as $1.7 million connected with leaving Raytheon Tech… [+1804 chars]'},
#   {'source': {'id': 'engadget', 'name': 'Engadget'},
#    'author': 'Engadget',
#    'title': 'The Morning After: Meet the new king of $399 GPUs',
#    'description': 'So after all the drama, how did the Cyberpunk 2077 launch work out for CD Projekt Red? While the numbers are still settling in, the company posted a note to its website for investors saying that, including requests received for refunds, the game sold 13 milli…',
#    'url': 'https://www.engadget.com/nvidia-rtx-3060-ti-review-tma-123800545.html',
#    'urlToImage': 'https://o.aolcdn.com/images/dims?resize=1200%2C630&crop=1200%2C630%2C0%2C0&quality=95&image_uri=https%3A%2F%2Fs.yimg.com%2Fos%2Fcreatr-uploaded-images%2F2020-12%2Fb2a8df50-451a-11eb-8cbe-2850d36cb92f&client=amp-blogside-v2&signature=1c7a8c5ef6bdecfe8efecdf296ea568981c892d5',
#    'publishedAt': '2020-12-23T12:38:00Z',
#    'content': 'So after all the drama, how did the Cyberpunk 2077 launch work out for CD Projekt Red? While the numbers are still settling in, the company posted a note to its website for investors saying that, inc… [+2114 chars]'},
#   {'source': {'id': 'cnn', 'name': 'CNN'},
#    'author': None,
#    'title': 'Watch this rocket launch from the wing of a jumbo jet',
#    'description': 'Virgin Orbit completed its first successful launch into orbit, sending its LauncherOne hurtling to space after deploying from the wing of a retrofitted Boeing 747.',
#    'url': 'https://www.cnn.com/videos/business/2021/01/18/virgin-orbit-rocket-launch-boeing-747-lc-orig.cnn',
#    'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/210118095835-virgin-orbit-super-tease.jpg',
#    'publishedAt': '2021-01-18T17:07:11Z',
#    'content': None},
#   {'source': {'id': 'cnn', 'name': 'CNN'},
#    'author': None,
#    'title': 'See how neighborhood made delivery driver cry tears of joy',
#    'description': "Residents of a Virginia neighborhood wanted to do something special for their local UPS delivery driver who they say brought a little joy to their lives during the pandemic. WTVR's Tracy Sears reports.",
#    'url': 'https://www.cnn.com/videos/us/2020/12/23/neighborhood-surprises-delivery-driver-dnt-vpx.wtvr',
#    'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/201222201321-neighborhood-surprises-delivery-driver-dnt-vpx-00020603-super-tease.png',
#    'publishedAt': '2020-12-23T01:16:50Z',
#    'content': None},
#   {'source': {'id': None, 'name': 'New York Times'},
#    'author': 'Kevin Draper',
#    'title': 'Grown-Ups Loved the N.F.L. on Nickelodeon. But What About Children?',
#    'description': 'The cable channel aired a slime-filled version of the Bears-Saints wild-card game on Sunday, to the delight of many adults. But the goal was to convert children into football fans.',
#    'url': 'https://www.nytimes.com/2021/01/11/sports/football/nfl-nickelodeon-bears-saints.html',
#    'urlToImage': 'https://static01.nyt.com/images/2021/01/11/sports/11nfl-nickelodeon-vp/11nfl-nickelodeon-vp-facebookJumbo.jpg',
#    'publishedAt': '2021-01-11T20:25:52Z',
#    'content': 'But the sports media landscape has changed since then. Nickelodeon has a new president, Brian Robbins. It is also part of a new corporate structure, which brings with it different imperatives. In 201… [+2248 chars]'},
#   {'source': {'id': 'engadget', 'name': 'Engadget'},
#    'author': 'Devindra Hardawar',
#    'title': 'Podcast: Everything that matters at CES 2021',
#    'description': 'We lived through CES 2021 and all we have to show for it is our tired typing fingers. This week, Devindra, Cherlynn and UK Bureau Chief Mat Smith chat about the most notable announcements from the show. Sure, there were tons of TVs, but PC hardware like AMD’s…',
#    'url': 'https://www.engadget.com/engadget-podcast-ces-2021-133001648.html',
#    'urlToImage': 'https://o.aolcdn.com/images/dims?resize=1200%2C630&crop=1200%2C630%2C0%2C0&quality=95&image_uri=https%3A%2F%2Fs.yimg.com%2Fos%2Fcreatr-uploaded-images%2F2020-05%2Ff43b53b0-909f-11ea-87fd-d8d721459924&client=amp-blogside-v2&signature=6bb88ddd7a6a497550658b4fa339ad9bdaaeab96',
#    'publishedAt': '2021-01-14T13:30:01Z',
#    'content': 'We lived through CES 2021 and all we have to show for it is our tired typing fingers. This week, Devindra, Cherlynn and UK Bureau Chief Mat Smith chat about the most notable announcements from the sh… [+613 chars]'}]}

# %%
# Fetch the XLV - Healthcare Sector news articles
health_headlines = newsapi.get_everything(q="(AmericanHealthcareSector OR JNJ OR Johnson & Johnson OR United Health Group OR UNH OR MRK OR Merck & Co OR PFE OR Pfizer OR ABT OR Abbott Laboratories OR ABBV OR AbbVie Inc OR TMO OR ThermoFisher OR Visa OR Nvidia OR BMY OR Bristol-MyersSquibb)",
                                           language="en",
                                           sort_by="relevancy")
health_headlines
# Out:
# {'status': 'ok',
#  'totalResults': 154759,
#  'articles': [{'source': {'id': None, 'name': 'New York Times'},
#    'author': 'Sharon LaFraniere and Katie Thomas',
#    'title': 'Pfizer Nears Deal to Provide More Vaccine Doses',
#    'description': 'The company could provide at least tens of millions of additional doses of a coronavirus vaccine under an agreement that would give it better access to the supplies it needs to expand manufacturing.',
#    'url': 'https://www.nytimes.com/2020/12/22/us/politics/pfizer-vaccine-doses.html',
#    'urlToImage': 'https://static01.nyt.com/images/2020/12/18/us/politics/18dc-pfizer-1/merlin_181350585_f21fe440-e7ea-4f83-85ac-5779414b526f-facebookJumbo.jpg',
#    'publishedAt': '2020-12-22T23:17:21Z',
#    'content': 'According to a report last month by the Government Accountability Office, the Defense Production Act gives the federal government vast authority over private companies, including the power to prevent… [+1810 chars]'},
#   {'source': {'id': None, 'name': 'New York Times'},
#    'author': 'Stephen Castle and Mark Landler',
#    'title': 'Britain Re-Enters Lockdown as Virus Variant Rages',
#    'description': 'Prime Minister Boris Johnson closes schools and declares a national lockdown in England, following on the heels of Scotland.',
#    'url': 'https://www.nytimes.com/2021/01/04/world/europe/britain-re-enters-lockdown-as-virus-variant-rages.html',
#    'urlToImage': 'https://static01.nyt.com/images/2021/01/04/world/04virus-uk/04virus-uk-facebookJumbo.jpg',
#    'publishedAt': '2021-01-04T20:05:54Z',
#    'content': 'Further steps must now be taken to arrest this rise and to protect the National Health Service and save lives, Mr. Johnsons office said in a statement. \r\nPeople in England will be encouraged to obey … [+1977 chars]'},
#   {'source': {'id': None, 'name': 'New York Times'},
#    'author': 'Stephen Castle and Mark Landler',
#    'title': 'UK Lockdown: Nation Re-Enters Lockdown as Coronavirus Variant Rages',
#    'description': 'Prime Minister Boris Johnson closes schools and declares a national lockdown in England, following on the heels of Scotland.',
#    'url': 'https://www.nytimes.com/2021/01/04/world/europe/uk-lockdown.html',
#    'urlToImage': 'https://static01.nyt.com/images/2021/01/04/world/04virus-uk5/04virus-uk5-facebookJumbo.jpg',
#    'publishedAt': '2021-01-04T20:27:00Z',
#    'content': 'Further steps must now be taken to arrest this rise and to protect the National Health Service and save lives, Mr. Johnsons office said in a statement. \r\nPeople in England will be encouraged to obey … [+1977 chars]'},
#   {'source': {'id': None, 'name': 'New York Times'},
#    'author': 'Sharon LaFraniere and Katie Thomas',
#    'title': 'Pfizer Nears Deal With Trump Administration to Provide More Vaccine Doses',
#    'description': 'The company could provide at least tens of millions of additional doses of a coronavirus vaccine under an agreement that would give it better access to the supplies it needs to expand manufacturing.',
#    'url': 'https://www.nytimes.com/2020/12/22/us/pfizer-vaccine-trump-administration.html',
#    'urlToImage': 'https://static01.nyt.com/images/2020/12/18/us/politics/18dc-pfizer-1/merlin_181350585_f21fe440-e7ea-4f83-85ac-5779414b526f-facebookJumbo.jpg',
#    'publishedAt': '2020-12-22T21:33:31Z',
#    'content': 'According to a report last month by the Government Accountability Office, the Defense Production Act gives the federal government vast authority over private companies, including the power to prevent… [+1810 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Sangmi Cha',
#    'title': 'South Korea signs deals to secure COVID-19 vaccine with Pfizer and Janssen - Reuters UK',
#    'description': 'South Korea has signed deals with Pfizer Inc and Johnson & Johnson’s Janssen to import coronavirus vaccines for 10 million people and 6 million, respectively, Prime Minister Chung Sye-kyun told a televised briefing on Thursday.',
#    'url': 'https://uk.reuters.com/article/us-health-coronavirus-southkorea-vaccine-idUKKBN28X2TL',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20201224&t=2&i=1545616350&r=LYNXMPEGBM1ID&w=800',
#    'publishedAt': '2020-12-24T00:02:00Z',
#    'content': 'SEOUL (Reuters) -South Korea has signed deals with Pfizer Inc and Johnson &amp; Johnsons Janssen to import coronavirus vaccines for 10 million people and 6 million, respectively, Prime Minister Chung… [+827 chars]'},
#   {'source': {'id': None, 'name': 'New York Times'},
#    'author': 'Thomas Kaplan and Rebecca Robbins',
#    'title': 'Biden Criticizes Trump on Vaccine Distribution and Pledges to Pick Up Pace',
#    'description': 'Three weeks from taking office, Joe Biden called vaccinating Americans “the greatest operational challenge we’ve ever faced as a nation” and offered a bleak assessment of the months ahead.',
#    'url': 'https://www.nytimes.com/2020/12/29/us/politics/biden-coronavirus-vaccines.html',
#    'urlToImage': 'https://static01.nyt.com/images/2020/12/29/us/politics/29dc-biden/29dc-biden-facebookJumbo.jpg',
#    'publishedAt': '2020-12-30T00:41:13Z',
#    'content': 'Pfizer has also agreed to provide 200 million doses. With each person requiring two shots, it leaves the supply 120 million doses short.\r\nOver the summer, before its vaccine had been shown to be effe… [+1751 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'Factbox: When and which COVID-19 vaccines are likely to be available in Asia - Reuters India',
#    'description': 'Regulators in Asia are weighing approval for COVID-19 vaccines developed by Pfizer Inc with partner BioNTech SE, Moderna Inc and AstraZeneca Plc, but few nations expect to get significant supplies initially.',
#    'url': 'https://in.reuters.com/article/health-coronavirus-vaccines-asia-idINKBN2940EY',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20201230&t=2&i=1546119670&r=LYNXMPEGBT081&w=800',
#    'publishedAt': '2020-12-30T05:41:00Z',
#    'content': 'By Reuters Staff\r\n(Reuters) - Regulators in Asia are weighing approval for COVID-19 vaccines developed by Pfizer Inc with partner BioNTech SE, Moderna Inc and AstraZeneca Plc, but few nations expect … [+5487 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'Factbox-When and which COVID-19 vaccines are likely to be available in Asia - Reuters',
#    'description': 'Regulators in Asia are weighing approval for COVID-19 vaccines developed by Pfizer Inc with partner BioNTech SE, Moderna Inc and AstraZeneca Plc, but few nations expect to get significant supplies initially.',
#    'url': 'https://www.reuters.com/article/us-health-coronavirus-vaccines-asia-fact-idUSKBN29C0N2',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210107&t=2&i=1546916397&r=LYNXMPEH060DS&w=800',
#    'publishedAt': '2021-01-07T06:22:00Z',
#    'content': 'By Reuters Staff\r\n(Reuters) - Regulators in Asia are weighing approval for COVID-19 vaccines developed by Pfizer Inc with partner BioNTech SE, Moderna Inc and AstraZeneca Plc, but few nations expect … [+5739 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'Germany says it needs third COVID vaccine to make inoculation universal - Reuters',
#    'description': 'Germany could offer shots against the coronavirus to all who want them by the summer if a third vaccine from either Johnson & Johnson, AstraZeneca or CureVac wins EU approval, Health Minister Jens Spahn said on Tuesday.',
#    'url': 'https://www.reuters.com/article/us-health-coronavirus-germany-spahn-idUSKBN2931UG',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20201229&t=2&i=1546082131&r=LYNXMPEGBS10A&w=800',
#    'publishedAt': '2020-12-29T18:59:00Z',
#    'content': 'By Reuters Staff\r\nBERLIN (Reuters) - Germany could offer shots against the coronavirus to all who want them by the summer if a third vaccine from either Johnson &amp; Johnson, AstraZeneca or CureVac … [+2236 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'Factbox: Latest on worldwide spread of the coronavirus - Reuters India',
#    'description': "Singapore confirmed its first case of the new coronavirus variant found in Britain, while Irish health chiefs said the mutation was present in Ireland though it was not solely responsible for the disease's rapid spread.",
#    'url': 'https://in.reuters.com/article/health-coronavirus-latest-idINKBN28Y0MB',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20201224&t=2&i=1545645678&r=LYNXMPEGBN0BV&w=800',
#    'publishedAt': '2020-12-24T07:03:00Z',
#    'content': 'By Reuters Staff\r\n(Reuters) - Singapore confirmed its first case of the new coronavirus variant found in Britain, while Irish health chiefs said the mutation was present in Ireland though it was not … [+3879 chars]'},
#   {'source': {'id': 'cnn', 'name': 'CNN'},
#    'author': 'Jen Christensen, CNN',
#    'title': 'More vaccines could be coming soon and they could be a big boost to the rollout',
#    'description': 'States may be scrambling for vaccines now, but the United States could see additional Covid-19 vaccines by the end of March, if not sooner.',
#    'url': 'https://www.cnn.com/2021/01/22/health/covid-19-vaccines-johnson-and-johnson-next/index.html',
#    'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/210121161008-14-week-in-photos-0120-super-tease.jpg',
#    'publishedAt': '2021-01-22T19:00:30Z',
#    'content': '(CNN)States may be scrambling for vaccines now, but the United States could see additional Covid-19 vaccines by the end of March, if not sooner.\r\nMillions of vaccine doses could be added to the pipel… [+6100 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Maria Cervantes',
#    'title': "Peruvian minister raises 'controversy' over Pfizer vaccine liability clause - Reuters",
#    'description': 'Peru\'s health minister said on Tuesday that "controversy" had arisen over a liability waiver in the country\'s negotiations to obtain COVID-19 vaccines from Pfizer Inc.',
#    'url': 'https://www.reuters.com/article/us-health-coronavirus-peru-vaccines-idUSKBN29A2J7',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210105&t=2&i=1546710420&r=LYNXMPEH041CW&w=800',
#    'publishedAt': '2021-01-05T21:11:00Z',
#    'content': 'LIMA (Reuters) - Perus health minister said on Tuesday that controversy had arisen over a liability waiver in the countrys negotiations to obtain COVID-19 vaccines from Pfizer Inc.\r\nA small shopping … [+1895 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Sangmi Cha',
#    'title': 'S.Korea to import J&J, Pfizer COVID-19 vaccines for 16 million people - Reuters UK',
#    'description': 'South Korea has signed deals with Pfizer Inc and Johnson & Johnson’s Janssen to import coronavirus vaccines to cover up to 16 million people, as it grapples with the third wave of infections, Prime Minister Chung Sye-kyun told a televised briefing on Thursday.',
#    'url': 'https://uk.reuters.com/article/uk-health-coronavirus-southkorea-vaccine-idUKKBN28Y05M',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20201224&t=2&i=1545622759&r=LYNXMPEGBN02M&w=800',
#    'publishedAt': '2020-12-24T01:37:00Z',
#    'content': 'SEOUL (Reuters) - South Korea has signed deals with Pfizer Inc and Johnson &amp; Johnsons Janssen to import coronavirus vaccines to cover up to 16 million people, as it grapples with the third wave o… [+1696 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'Colombia regulator approves Pfizer-BioNTech vaccine for emergency use - Reuters',
#    'description': "Colombia's food and drug regulator on Tuesday authorized emergency use of Pfizer Inc and BioNTech SE's COVID-19 vaccine, President Ivan Duque said on Tuesday, joining other countries that have already approved coronavirus vaccines.",
#    'url': 'https://www.reuters.com/article/us-health-coronavirus-colombia-vaccine-idUSKBN29B02M',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210106&t=2&i=1546728585&r=LYNXMPEH0501B&w=800',
#    'publishedAt': '2021-01-06T00:56:00Z',
#    'content': 'By Reuters Staff\r\nFILE PHOTO: Syringes are seen in front of displayed Biontech and Pfizer logos in this illustration taken November 10, 2020. REUTERS/Dado Ruvic\r\nBOGOTA (Reuters) - Colombias food and… [+1399 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'Explainer-Where are we in the COVID-19 vaccine race? - Reuters India',
#    'description': "European Union gave approval on Dec. 21 for the COVID-19 vaccine developed by Pfizer Inc and BioNTech SE, the latest regulatory go-ahead for the shot, while the United States authorised Moderna Inc's vaccine on Dec. 19, the second for the country and the firs…",
#    'url': 'https://in.reuters.com/article/health-coronavirus-vaccines-explainer-idINKBN2910DX',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20201227&t=2&i=1545887010&r=LYNXMPEGBQ07C&w=800',
#    'publishedAt': '2020-12-27T12:13:00Z',
#    'content': 'By Reuters Staff\r\n(Reuters) - European Union gave approval on Dec. 21 for the COVID-19 vaccine developed by Pfizer Inc and BioNTech SE, the latest regulatory go-ahead for the shot, while the United S… [+5641 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'South Africa to get 9 million J&J vaccine shots - ministry - Reuters',
#    'description': 'South Africa, which has yet to receive its first coronavirus vaccine doses, will be getting 9 million from Johnson & Johnson, the health ministry said on Monday.',
#    'url': 'https://www.reuters.com/article/uk-health-coronavirus-safrica-vaccine/south-africa-to-get-9-million-jj-vaccine-shots-ministry-idUSKBN29N1D9',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210118&t=2&i=1548208139&r=LYNXMPEH0H0W8&w=800',
#    'publishedAt': '2021-01-18T15:25:00Z',
#    'content': 'By Reuters Staff\r\nJOHANNESBURG (Reuters) - South Africa, which has yet to receive its first coronavirus vaccine doses, will be getting 9 million from Johnson &amp; Johnson, the health ministry said o… [+2025 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'UPDATE 1-South Africa to get 9 million J&J vaccine shots - ministry - Reuters',
#    'description': 'South Africa, which has yet to receive its first coronavirus vaccine doses, will be getting 9 million from Johnson & Johnson, the health ministry said on Monday.',
#    'url': 'https://www.reuters.com/article/health-coronavirus-safrica-vaccine/update-1-south-africa-to-get-9-million-jj-vaccine-shots-ministry-idUSL1N2JT0WA',
#    'urlToImage': 'https://s1.reutersmedia.net/resources_v2/images/rcom-default.png?w=800',
#    'publishedAt': '2021-01-18T13:34:00Z',
#    'content': 'By Reuters Staff\r\n(Changes sourcing, adds detail on AU doses)\r\nJOHANNESBURG, Jan 18 (Reuters) - South Africa, which has yet to receive its first coronavirus vaccine doses, will be getting 9 million f… [+1893 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'J&J likely to apply for EU approval for COVID vaccine in February -lawmaker - Reuters',
#    'description': 'U.S. firm Johnson & Johnson is likely to apply for EU approval for its COVID-19 vaccine candidate in February, a top lawmaker said on Wednesday.',
#    'url': 'https://www.reuters.com/article/healthcoronavirus-vaccine-eu-johnsonjohn/jj-likely-to-apply-for-eu-approval-for-covid-vaccine-in-february-lawmaker-idUSB5N2B301P',
#    'urlToImage': 'https://s1.reutersmedia.net/resources_v2/images/rcom-default.png?w=800',
#    'publishedAt': '2021-01-13T11:42:00Z',
#    'content': 'By Reuters Staff\r\nBRUSSELS, Jan 13 (Reuters) - U.S. firm Johnson &amp; Johnson is likely to apply for EU approval for its COVID-19 vaccine candidate in February, a top lawmaker said on Wednesday.\r\nEU… [+417 chars]'},
#   {'source': {'id': None, 'name': 'New York Times'},
#    'author': 'Sharon LaFraniere and Zach Montague',
#    'title': 'U.S. and Pfizer Seal Deal for 100 Million More Vaccine Doses',
#    'description': 'The company agreed to deliver the additional doses of its coronavirus vaccine by the end of July, helping address a looming shortage.',
#    'url': 'https://www.nytimes.com/2020/12/23/us/politics/pfizer-vaccine-doses-virus.html',
#    'urlToImage': 'https://static01.nyt.com/images/2020/12/18/us/politics/18dc-pfizer-1/merlin_181350585_f21fe440-e7ea-4f83-85ac-5779414b526f-facebookJumbo.jpg',
#    'publishedAt': '2020-12-23T21:58:33Z',
#    'content': 'Others familiar with the negotiations said the government expressed concern that prioritizing Pfizer could squeeze the supply chain, hindering the other vaccine makers that the government was backing… [+3791 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Vishwadha Chander',
#    'title': "UPDATE 1-Abbott's COVID-19 antigen test may help with faster detection, isolation - CDC - Reuters",
#    'description': "Abbott Laboratories' rapid COVID-19 antigen test is highly likely to correctly detect if people have ever contracted the virus and could help with earlier isolation, according to the U.S. Centers for Disease Control and Prevention.",
#    'url': 'https://www.reuters.com/article/us-health-coronavirus-abbott-testing-idUSKBN29O2DD',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210119&t=2&i=1548347119&r=LYNXMPEH0I1FO&w=800',
#    'publishedAt': '2021-01-19T20:56:00Z',
#    'content': '(Reuters) - Abbott Laboratories rapid COVID-19 antigen test is highly likely to correctly detect if people have ever contracted the virus and could help with earlier isolation, according to the U.S. … [+2257 chars]'}]}

# %%
# Fetch the XLE - Energy Sector news articles
energy_headlines = newsapi.get_everything(q="AmericanEnergySector OR XOM OR Exxon Mobil OR CVX OR Chevron OR PSX OR SLB OR Schlumberger OR COP OR ConcoPhillips OR Phillips 66 OR EOG OR EOG Resources OR MPC OR Marathon Petrolem OR KMI OR KinderMorgan Inc OR WMB OR WillliamsCompanies Inc OR VLO OR ValeroEnergyCorp",
                                           language="en",
                                           sort_by="relevancy")
energy_headlines
# Out:
# {'status': 'ok',
#  'totalResults': 102504,
#  'articles': [{'source': {'id': 'business-insider',
#     'name': 'Business Insider'},
#    'author': 'Benji Jones',
#    'title': "Bank of America's top oil and gas researcher explains why now is the time to invest in energy and names his 15 top stock picks — including 3 that can't be beat",
#    'description': 'Summary List PlacementMost energy analysts would call 2020 an unprecedented year for oil markets. Last spring, the pandemic dried up demand for crude, right as two top producing nations engaged in a price war — a destructive double blow that sent oil prices t…',
#    'url': 'https://www.businessinsider.com/bank-of-america-oil-researcher-energy-stocks-to-buy-top-picks-2021-1',
#    'urlToImage': 'https://i.insider.com/60085131660f6c0018349f44?width=1200&format=jpeg',
#    'publishedAt': '2021-01-20T16:32:33Z',
#    'content': 'Most energy analysts would call 2020 an unprecedented year for oil markets. Last spring, the pandemic dried up demand for crude, right as two top producing nations engaged in a price war — a destruct… [+5641 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'J.P. Morgan upgrades Exxon to overweight for first time in seven years - Reuters',
#    'description': 'J.P. Morgan analysts on Wednesday raised their rating on shares of Exxon Mobil to overweight, its first outright "buy" recommendation for the oil major in seven years, saying cuts in capital spending had put it on track for a stronger performance.',
#    'url': 'https://www.reuters.com/article/us-exxon-mobil-research-jpm/jp-morgan-upgrades-exxon-to-overweight-for-first-time-in-seven-years-idUSKBN29I17Y',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210113&t=2&i=1547616751&r=LYNXMPEH0C0PB&w=800',
#    'publishedAt': '2021-01-13T10:56:00Z',
#    'content': 'By Reuters Staff\r\n(Reuters) - J.P. Morgan analysts on Wednesday raised their rating on shares of Exxon Mobil to overweight, its first outright buy recommendation for the oil major in seven years, say… [+1773 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'David Shepardson, Diane Bartz',
#    'title': "Corporate group urges officials consider Trump's removal 'to preserve democracy' - Reuters India",
#    'description': 'The head of a major U.S. business group that represents 14,000 companies including Exxon Mobil Corp, Pfizer Inc and Toyota Motor Corp urged senior U.S. officials to consider removing President Donald Trump from office after supporters of the outgoing presiden…',
#    'url': 'https://in.reuters.com/article/usa-election-companies-idINKBN29C07I',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210107&t=2&i=1546888213&r=LYNXMPEH0604G&w=800',
#    'publishedAt': '2021-01-07T02:06:00Z',
#    'content': 'WASHINGTON (Reuters) - The head of a major U.S. business group that represents 14,000 companies including Exxon Mobil Corp, Pfizer Inc and Toyota Motor Corp urged senior U.S. officials to consider re… [+4439 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'David Shepardson, Diane Bartz',
#    'title': "Corporate group urges officials consider Trump's removal 'to preserve democracy' - Reuters",
#    'description': 'The head of a major U.S. business group that represents 14,000 companies including Exxon Mobil Corp, Pfizer Inc and Toyota Motor Corp urged senior U.S. officials to consider removing President Donald Trump from office after supporters of the outgoing presiden…',
#    'url': 'https://www.reuters.com/article/usa-election-companies-int-idUSKBN29C08L',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210107&t=2&i=1546890118&r=LYNXMPEH0605A&w=800',
#    'publishedAt': '2021-01-07T02:21:00Z',
#    'content': 'WASHINGTON (Reuters) - The head of a major U.S. business group that represents 14,000 companies including Exxon Mobil Corp, Pfizer Inc and Toyota Motor Corp urged senior U.S. officials to consider re… [+4439 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'David Shepardson, Diane Bartz',
#    'title': 'UPDATE 1-Corporate group urges officials to consider quick removal of Trump - Reuters India',
#    'description': 'The head of a major U.S. business group that represents 14,000 companies including Exxon Mobil Corp, Pfizer Inc and Toyota Motor Corp urged senior U.S. officials to consider removing President Donald Trump from office after supporters of the outgoing presiden…',
#    'url': 'https://in.reuters.com/article/usa-election-companies-idINL1N2JH2YD',
#    'urlToImage': 'https://s1.reutersmedia.net/resources_v2/images/rcom-default.png?w=800',
#    'publishedAt': '2021-01-06T22:30:00Z',
#    'content': '(Adds more business groups)\r\nWASHINGTON, Jan 6 (Reuters) - The head of a major U.S. business group that represents 14,000 companies including Exxon Mobil Corp, Pfizer Inc and Toyota Motor Corp urged … [+2048 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'David Shepardson, Diane Bartz',
#    'title': "Corporate group urges officials consider Trump's removal 'to preserve democracy' - Reuters UK",
#    'description': 'The head of a major U.S. business group that represents 14,000 companies including Exxon Mobil Corp, Pfizer Inc and Toyota Motor Corp urged senior U.S. officials to consider removing President Donald Trump from office after supporters of the outgoing presiden…',
#    'url': 'https://uk.reuters.com/article/uk-usa-election-companies-idUKKBN29C07K',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210107&t=2&i=1546888136&r=LYNXMPEH0604L&w=800',
#    'publishedAt': '2021-01-07T02:05:00Z',
#    'content': 'WASHINGTON (Reuters) - The head of a major U.S. business group that represents 14,000 companies including Exxon Mobil Corp, Pfizer Inc and Toyota Motor Corp urged senior U.S. officials to consider re… [+4428 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': "Exxon Mobil lifts force majeure on exports of Nigeria's Qua Iboe crude oil - spokesman - Reuters.com",
#    'description': "Exxon Mobil has lifted a force majeure on Nigeria's Qua Iboe crude oil export terminal, a spokesman said on Friday.",
#    'url': 'https://www.reuters.com/article/us-nigeria-oil-exxon-mobil-idUSKBN29R26I',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210122&t=2&i=1548738249&r=LYNXMPEH0L18L&w=800',
#    'publishedAt': '2021-01-22T17:06:00Z',
#    'content': 'By Reuters Staff\r\nFILE PHOTO: The logo of Exxon Mobil is seen in Encinitas, California April 4, 2016. REUTERS/Mike Blake\r\nABUJA (Reuters) - Exxon Mobil has lifted a force majeure on Nigerias Qua Iboe… [+244 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Joe Brock, John Geddie, Saurabh Sharma',
#    'title': "Big Oil's flagship plastic waste project sinks on the Ganges - Reuters",
#    'description': 'A wheelbarrow and a handful of metal grids for capturing litter, emblazoned with the words “Renew Oceans,” sit rusting outside an empty, padlocked office in the Indian city of Varanasi, a short walk from the Ganges.',
#    'url': 'https://www.reuters.com/article/us-environment-plastic-insight/big-oils-flagship-plastic-waste-project-sinks-on-the-ganges-idUSKBN29N024',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210118&t=2&i=1548140292&r=LYNXMPEH0H014&w=800',
#    'publishedAt': '2021-01-18T01:08:00Z',
#    'content': 'SINGAPORE/VARANASI, India (Reuters) - A wheelbarrow and a handful of metal grids for capturing litter, emblazoned with the words Renew Oceans, sit rusting outside an empty, padlocked office in the In… [+6792 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Joe Brock, John Geddie, Saurabh Sharma',
#    'title': "Big Oil's flagship plastic waste project sinks on the Ganges - Reuters India",
#    'description': 'A wheelbarrow and a handful of metal grids for capturing litter, emblazoned with the words “Renew Oceans,” sit rusting outside an empty, padlocked office in the Indian city of Varanasi, a short walk from the Ganges.',
#    'url': 'https://www.reuters.com/article/environment-plastic/big-oils-flagship-plastic-waste-project-sinks-on-the-ganges-idUSKBN29N028',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210118&t=2&i=1548140292&r=LYNXMPEH0H014&w=800',
#    'publishedAt': '2021-01-18T01:08:00Z',
#    'content': 'SINGAPORE/VARANASI, India (Reuters) - A wheelbarrow and a handful of metal grids for capturing litter, emblazoned with the words Renew Oceans, sit rusting outside an empty, padlocked office in the In… [+6792 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Joe Brock, John Geddie, Saurabh Sharma',
#    'title': "RPT-INSIGHT-Big Oil's flagship plastic waste project sinks on the Ganges - Reuters",
#    'description': 'A wheelbarrow and a handful of metal grids for capturing litter, emblazoned with the words “Renew Oceans,” sit rusting outside an empty, padlocked office in the Indian city of Varanasi, a short walk from the Ganges.',
#    'url': 'https://www.reuters.com/article/environment-plastic/rpt-insight-big-oils-flagship-plastic-waste-project-sinks-on-the-ganges-idUSL1N2JT0II',
#    'urlToImage': 'https://s1.reutersmedia.net/resources_v2/images/rcom-default.png?w=800',
#    'publishedAt': '2021-01-18T08:56:00Z',
#    'content': '(Repeats to additional subscribers)\r\nSINGAPORE/VARANASI, India, Jan 18 (Reuters) - A wheelbarrow and a handful of metal grids for capturing litter, emblazoned with the words Renew Oceans, sit rusting… [+6639 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Devik Jain, Supriya R',
#    'title': 'US STOCKS-S&P, Nasdaq futures at record levels as Trump signs stimulus aid bill - Reuters',
#    'description': "Futures tracking the S&P 500 and the Nasdaq were at record levels on Monday as President Donald Trump's move to sign into law a long-awaited $2.3 trillion pandemic aid bill bolstered bets on a vaccine-led economic recovery.",
#    'url': 'https://www.reuters.com/article/us-usa-stocks-idUSKBN292101',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20201228&t=2&i=1545959094&r=LYNXMPEGBR0GQ&w=800',
#    'publishedAt': '2020-12-28T12:30:00Z',
#    'content': '(Reuters) - Futures tracking the S&amp;P 500 and the Nasdaq were at record levels on Monday as President Donald Trumps move to sign into law a long-awaited $2.3 trillion pandemic aid bill bolstered b… [+2220 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Jennifer Hiller, Nichola Groom',
#    'title': 'Big U.S. oil drillers have federal permits to mute effect of any Biden ban - Reuters',
#    'description': "U.S. President Joe Biden's promised ban on new oil and gas drilling on federal lands would take years to shut off production from top shale drillers because they already have stockpiled permits, according to Reuters interviews with executives.",
#    'url': 'https://www.reuters.com/article/us-usa-biden-drilling-idUSKBN29Q1S5',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210121&t=2&i=1548585719&r=LYNXMPEH0K0X1&w=800',
#    'publishedAt': '2021-01-21T13:45:00Z',
#    'content': '(Reuters) - U.S. President Joe Bidens promised ban on new oil and gas drilling on federal lands would take years to shut off production from top shale drillers because they already have stockpiled pe… [+5642 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Chuck Mikolajczak',
#    'title': 'Tesla bears suffer record short-sale loss in 2020: S3 Partners - Reuters',
#    'description': "Short bets on Tesla Inc were the most unprofitable trade in 2020, as the electric automaker saw its shares surge over 740% en route to becoming the world's most valuable automaker.",
#    'url': 'https://www.reuters.com/article/us-usa-stocks-shortsellers-idUSKBN29Q2WN',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210121&t=2&i=1548632809&r=LYNXMPEH0K1ND&w=800',
#    'publishedAt': '2021-01-21T21:25:00Z',
#    'content': 'FILE PHOTO: People walk in front of the New York Stock Exchange (NYSE) in New York, U.S., January 15, 2021. REUTERS/Brendan McDermid\r\nNEW YORK (Reuters) - Short bets on Tesla Inc were the most unprof… [+1755 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'George Hay, Lauren Silva Laughlin',
#    'title': 'Breakingviews - Chevron makes bet on being last man standing - Reuters',
#    'description': 'Chevron Chief Executive Mike Wirth is doubling down on oil. The boss of the $180 billion U.S. fossil fuel firm told Reuters on Tuesday that he was a fan of the 2015 Paris Agreement to cut carbon emissions, but also didn’t think crude demand would permanently …',
#    'url': 'https://www.reuters.com/article/us-chevron-ceo-breakingviews/breakingviews-chevron-makes-bet-on-being-last-man-standing-idUSKBN29H2U2',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210112&t=2&i=1547543769&r=LYNXMPEH0B1IA&w=800',
#    'publishedAt': '2021-01-12T21:19:00Z',
#    'content': 'A Chevron gas station sign is seen in Cardiff, California, U.S. January 25, 2016. REUTERS/Mike Blake/File Photo\r\nLONDON/NEW YORK (Reuters Breakingviews) - Chevron Chief Executive Mike Wirth is doubli… [+2839 chars]'},
#   {'source': {'id': None, 'name': 'MarketWatch'},
#    'author': 'Tomi Kilgore',
#    'title': 'The Ratings Game: Exxon Mobil stock rises again after J.P. Morgan analyst turns bullish for the first time in 7 years',
#    'description': 'Shares of Exxon Mobil Corp. rose Wednesday, putting them on track for the longest win streak in 16 months, after J.P. Morgan analyst Phil Gresh turned bullish on the oil giant for the first time, citing an improved financial outlook and more reasonable valuat…',
#    'url': 'https://www.marketwatch.com/story/exxon-mobil-stock-rises-again-after-j-p-morgan-analyst-turns-bullish-for-the-first-time-in-7-years-11610546672',
#    'urlToImage': 'https://images.mktw.net/im-284594/social',
#    'publishedAt': '2021-01-13T14:04:00Z',
#    'content': 'Shares of Exxon Mobil Corp. rose Wednesday, putting them on track for the longest win streak in 16 months, after J.P. Morgan analyst Phil Gresh turned bullish on the oil giant for the first time, cit… [+2210 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'Exxon, under investor pressure, discloses emissions from burning its fuels - Reuters',
#    'description': 'Exxon Mobil Corp, under increasing pressure from investors and climate change activists, reported for the first time the emissions that result when customers use its products such as gasoline and jet fuel.',
#    'url': 'https://www.reuters.com/article/us-exxon-mobil-carbon-idUSKBN29B2NQ',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210106&t=2&i=1546844589&r=LYNXMPEH051DW&w=800',
#    'publishedAt': '2021-01-06T19:36:00Z',
#    'content': 'By Reuters Staff\r\n(Reuters) - Exxon Mobil Corp, under increasing pressure from investors and climate change activists, reported for the first time the emissions that result when customers use its pro… [+1825 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'Exxon, under investor pressure, discloses emissions from burning its fuels - Reuters UK',
#    'description': 'Exxon Mobil Corp, under increasing pressure from investors and climate change activists, reported for the first time the emissions that result when customers use its products such as gasoline and jet fuel.',
#    'url': 'https://uk.reuters.com/article/us-exxon-mobil-carbon-idUKKBN29B2NQ',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210106&t=2&i=1546844589&r=LYNXMPEH051DW&w=800',
#    'publishedAt': '2021-01-06T19:34:00Z',
#    'content': 'By Reuters Staff\r\n(Reuters) - Exxon Mobil Corp, under increasing pressure from investors and climate change activists, reported for the first time the emissions that result when customers use its pro… [+1825 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Devik Jain, Supriya R',
#    'title': 'US STOCKS-S&P, Nasdaq futures at record levels as Trump signs stimulus aid bill - Reuters',
#    'description': '<ol><li>US STOCKS-S&P, Nasdaq futures at record levels as Trump signs stimulus aid bill\xa0\xa0Reuters\r\n</li><li>Stocks jump to records as Trump signs off on coronavirus aid\xa0\xa0Fox Business\r\n</li><li>Stock market news live updates: Stocks end at record highs after Tr…',
#    'url': 'https://fr.reuters.com/article/usa-stocks-idUSL4N2J81HR',
#    'urlToImage': 'https://s1.reutersmedia.net/resources_v2/images/rcom-default.png?w=800',
#    'publishedAt': '2020-12-28T12:37:07Z',
#    'content': '(For a Reuters live blog on U.S., UK and European stock markets, click LIVE/ or type LIVE/ in a news window.)\r\n* Futures up: S&amp;P 0.7%, Dow 0.6% and Nasdaq up 0.7%\r\nDec 28 (Reuters) - Futures trac… [+2304 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'Exxon signals up to $20 billion writedown to overwhelm fourth quarter price gains in oil, chemicals - Reuters',
#    'description': 'Exxon Mobil Corp signaled in a regulatory filing on Wednesday that higher oil and gas prices and improved chemicals margins would aid fourth quarter results, but the gains would be overshadowed by an up to $20 billion asset write down.',
#    'url': 'https://www.reuters.com/article/us-exxon-mobil-outlook-idUSKBN2942DV',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20201230&t=2&i=1546211676&r=LYNXMPEGBT1D8&w=800',
#    'publishedAt': '2020-12-30T22:10:00Z',
#    'content': 'By Reuters Staff\r\nFILE PHOTO: An Exxon sign is seen at a gas station in the Chicago suburb of Norridge, Illinois, U.S., October 27, 2016. REUTERS/Jim Young\r\nHOUSTON (Reuters) - Exxon Mobil Corp signa… [+526 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'Exxon signals up to $20 billion writedown to overwhelm fourth-quarter gains in oil, chemicals - Reuters India',
#    'description': 'Exxon Mobil Corp signaled in a regulatory filing that higher oil and gas prices and improved chemicals margins would aid fourth quarter results, but the gains would be overshadowed by an up to $20 billion asset write down.',
#    'url': 'https://in.reuters.com/article/exxon-mobil-outlook-idINKBN2950F3',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20201231&t=2&i=1546234186&r=LYNXMPEGBU071&w=800',
#    'publishedAt': '2020-12-31T05:13:00Z',
#    'content': 'By Reuters Staff\r\nHOUSTON (Reuters) - Exxon Mobil Corp signaled in a regulatory filing that higher oil and gas prices and improved chemicals margins would aid fourth quarter results, but the gains wo… [+2028 chars]'}]}

# %%
# Fetch the ETH - Ethereum news articles
ethereum_headlines = newsapi.get_everything(q="ethereum",
                                           language="en",
                                           sort_by="relevancy")
ethereum_headlines
# Out:
# {'status': 'ok',
#  'totalResults': 1421,
#  'articles': [{'source': {'id': 'business-insider',
#     'name': 'Business Insider'},
#    'author': 'William Edwards',
#    'title': "A crypto CEO breaks down why he would not be surprised to see Bitcoin and Ethereum rise at least 100% in 2021 — and says the current sell-offs are a 'very natural and healthy thing'",
#    'description': 'Summary List PlacementCryptocurrencies stole headlines on the first stock-market trading day of 2021, with bitcoin and ethereum selling off steeply after blistering run-ups over the weekend.\nBut investors need not worry about too sharp of a drop in the digita…',
#    'url': 'https://www.businessinsider.com/bitcoin-ethereum-price-forecasts-2021-upside-greg-king-osprey-funds-2021-1',
#    'urlToImage': 'https://i.insider.com/5ff381b76056b60018721d74?width=1200&format=jpeg',
#    'publishedAt': '2021-01-05T13:15:00Z',
#    'content': 'Cryptocurrencies stole headlines on the first stock-market trading day of 2021, with bitcoin and ethereum selling off steeply after blistering run-ups over the weekend.\r\nBut investors need not worry … [+2877 chars]'},
#   {'source': {'id': 'ars-technica', 'name': 'Ars Technica'},
#    'author': 'Timothy B. Lee',
#    'title': 'Ether soars above $1,000 in broad cryptocurrency rally',
#    'description': 'The value of all cryptocurrencies in circulation is more than $850 billion.',
#    'url': 'https://arstechnica.com/tech-policy/2021/01/ether-soars-above-1000-in-broad-cryptocurrency-rally/',
#    'urlToImage': 'https://cdn.arstechnica.net/wp-content/uploads/2017/11/36490685544_09623d813d_z-640x380.jpg',
#    'publishedAt': '2021-01-04T17:08:27Z',
#    'content': 'Ethereum creator Vitalik Buterin.\r\n14 with 11 posters participating\r\nEther, the native currency of the Ethereum network and the second most valuable cryptocurrency, has soared above $1,000 for the fi… [+3015 chars]'},
#   {'source': {'id': None, 'name': 'BNNBloomberg.ca'},
#    'author': 'Bloomberg News',
#    'title': 'Bitcoin rally comes to a halt as prices fall most since March - BNN',
#    'description': '<ol><li>Bitcoin rally comes to a halt as prices fall most since March\xa0\xa0BNN\r\n</li><li>Bitcoin, Ethereum Outlook: Cryptos Go Parabolic, is a Correction Due?\xa0\xa0DailyFX\r\n</li><li>Bitcoin slumps, slamming brakes on New Year rally\xa0\xa0The Globe and Mail\r\n</li><li>Bitco…',
#    'url': 'http://www.bnnbloomberg.ca/bitcoin-mania-reaches-new-heights-as-prices-go-parabolic-1.1543469',
#    'urlToImage': 'http://www.bnnbloomberg.ca/polopoly_fs/1.1468795!/fileimage/httpImage/image.jpg_gen/derivatives/landscape_620/bitcoin.jpg',
#    'publishedAt': '2021-01-04T13:58:21Z',
#    'content': 'Bitcoin fizzled in Monday trading as the famously volatile cryptocurrency pulled back after a spectacular new-year rally.\r\nPrices fell as much as 17 per cent in the biggest drop since March before re… [+2174 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'Bitcoin falls 5% to $37507 on Bitstamp exchange - Reuters',
#    'description': 'Bitcoin fell more than 5% on Friday, a day after topping $40,000 for the first time.',
#    'url': 'https://www.reuters.com/article/us-crypto-currency/bitcoin-falls-5-to-37507-on-bitstamp-exchange-idUSKBN29D0BF?feedType=mktg&feedName=ousivMolt&WT.mc_id=Partner-Google',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210108&t=2&i=1547047065&r=LYNXMPEH07049&w=800',
#    'publishedAt': '2021-01-08T02:48:37Z',
#    'content': 'By Reuters Staff\r\nFILE PHOTO: A representation of virtual currency bitcoin is seen in this illustration taken November 19, 2020. REUTERS/Dado Ruvic/Illustration\r\nTOKYO (Reuters) - Bitcoin fell more t… [+293 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'Bitcoin falls 5% to $37507 on Bitstamp exchange - Reuters',
#    'description': 'Bitcoin fell more than 5% on Friday, a day after topping $40,000 for the first time.',
#    'url': 'https://www.reuters.com/article/us-crypto-currency/bitcoin-falls-5-to-37507-on-bitstamp-exchange-idUSKBN29D0BF',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210108&t=2&i=1547047978&r=LYNXMPEH0704I&w=800',
#    'publishedAt': '2021-01-08T02:51:00Z',
#    'content': 'By Reuters Staff\r\nFILE PHOTO: A representation of virtual currency bitcoin is seen in this illustration taken November 19, 2020. REUTERS/Dado Ruvic/Illustration\r\nTOKYO (Reuters) - Bitcoin fell more t… [+293 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'Bitcoin hits one-week low as rising U.S. yields dent rally - Reuters',
#    'description': 'Cryptocurrencies plunged on Monday, with bitcoin dropping more than 12% to a one-week low as rising U.S. yields lifted the dollar broadly and hurt non-income paying assets.',
#    'url': 'https://www.reuters.com/article/crypto-currency/bitcoin-hits-one-week-low-as-rising-us-yields-dent-rally-idUSL4N2JM0QA',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210111&t=2&i=1547318703&r=LYNXMPEH0A04G&w=800',
#    'publishedAt': '2021-01-11T03:57:00Z',
#    'content': 'By Reuters Staff\r\nFILE PHOTO: A representation of virtual currency Bitcoin and small toy figures are placed on computer motherboard in this illustration taken January 7, 2021. REUTERS/Dado Ruvic\r\nSIN… [+351 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'Bitcoin hits one-week low as rising U.S. yields dent rally - Reuters',
#    'description': 'Cryptocurrencies plunged on Monday, with bitcoin dropping more than 12% to a one-week low as rising U.S. yields lifted the dollar broadly and hurt non-income paying assets.',
#    'url': 'https://www.reuters.com/article/us-crypto-currency/bitcoin-hits-one-week-low-as-rising-u-s-yields-dent-rally-idUSKBN29G08M',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210111&t=2&i=1547318703&r=LYNXMPEH0A04G&w=800',
#    'publishedAt': '2021-01-11T03:57:00Z',
#    'content': 'By Reuters Staff\r\nFILE PHOTO: A representation of virtual currency Bitcoin and small toy figures are placed on computer motherboard in this illustration taken January 7, 2021. REUTERS/Dado Ruvic\r\nSIN… [+351 chars]'},
#   {'source': {'id': None, 'name': 'PC Gamer'},
#    'author': 'Paul Lilly',
#    'title': 'This crypto-mining farm with 78 GeForce RTX 3080 GPUs likely rakes in $154,000 per year - PC Gamer',
#    'description': '<ol><li>This crypto-mining farm with 78 GeForce RTX 3080 GPUs likely rakes in $154,000 per year\xa0\xa0PC Gamer\r\n</li><li>Nvidia RTX 3080 is apparently coming to the most powerful gaming laptops\xa0\xa0TechRadar\r\n</li><li>MSI GeForce RTX 3080 SUPRIM X Review: Big, Bad An…',
#    'url': 'https://www.pcgamer.com/this-crypto-mining-farm-with-78-geforce-rtx-3080-gpus-likely-rakes-in-dollar154000-per-year/',
#    'urlToImage': 'https://cdn.mos.cms.futurecdn.net/rf9THsLa9ej546K8fw64wC-1200-80.jpg',
#    'publishedAt': '2020-12-31T13:13:00Z',
#    'content': 'It seems only fitting to end 2020 on a depressing note, and to that end, a cryptocurrency miner living in Las Vegas has apparently managed to procure dozens of PNY brand GeForce RTX 3080 cards to min… [+3181 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'Sequoia Holdings says employees can draw part of salary in cryptocurrencies - Reuters',
#    'description': 'Software development services provider Sequoia Holdings LLC said on Thursday its employees can now receive a part of their salary in cryptocurrencies, should they choose to.',
#    'url': 'https://www.reuters.com/article/us-sequoia-holdings-salary-bitcoin-idUSKBN29Q21G',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210121&t=2&i=1548594098&r=LYNXMPEH0K13S&w=800',
#    'publishedAt': '2021-01-21T14:53:00Z',
#    'content': 'By Reuters Staff\r\nFILE PHOTO: Representations of virtual currency Bitcoin are seen in this picture illustration taken taken March 13, 2020. REUTERS/Dado Ruvic/Illustration\r\n(Reuters) - Software devel… [+676 chars]'},
#   {'source': {'id': 'bloomberg', 'name': 'Bloomberg'},
#    'author': None,
#    'title': 'Bitcoin Holds Near Record, Ether Surges Amid Crypto Rally - Bloomberg',
#    'description': '<ol><li>Bitcoin Holds Near Record, Ether Surges Amid Crypto Rally\xa0\xa0Bloomberg\r\n</li><li>Bitcoin price passes new milestone of US$ 34000\xa0\xa0Arirang News\r\n</li><li>Ethereum Breaks Past $900 As Altcoins Go Nuts\xa0\xa0Decrypt\r\n</li><li>Bitcoin Blasts Past $34K for First …',
#    'url': 'https://www.bloomberg.com/tosv2.html?vid=&uuid=9ec43210-4e6a-11eb-b641-572cf808966a&url=L25ld3MvYXJ0aWNsZXMvMjAyMS0wMS0wNC9ldGhlci1mb2xsb3dzLWJpdGNvaW4tdG8tcmVjb3JkLWhpZ2gtYW1pZC1kaXp6eWluZy1jcnlwdG8tcmFsbHk=',
#    'urlToImage': None,
#    'publishedAt': '2021-01-04T01:44:00Z',
#    'content': None},
#   {'source': {'id': None, 'name': 'Sagivo.com'},
#    'author': None,
#    'title': 'Make passive income using Ethereum 2.0',
#    'description': 'Learn how to become eth2 validator and earn staking fees',
#    'url': 'https://sagivo.com/crypto/2020/12/26/Etherum2.0.html',
#    'urlToImage': None,
#    'publishedAt': '2020-12-26T22:35:05Z',
#    'content': 'Ethereum is one of the leading crypto projects (second to bitcoin). In December 2020 Ethereum released the first stage of Ethereum 2.0. The biggest difference is that there is no need for an expensiv… [+12510 chars]'},
#   {'source': {'id': None, 'name': 'Entrepreneur'},
#    'author': 'Sarah Austin',
#    'title': "How 2020 Became the Year of DeFi and What's to Come in 2021",
#    'description': 'What will be the biggest trend in 2021? Decentralized finance is geared up to be the biggest thing since Bitcoin.',
#    'url': 'https://www.entrepreneur.com/article/362319',
#    'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1610032210-GettyImages-1277771766.jpg',
#    'publishedAt': '2021-01-09T19:15:00Z',
#    'content': 'January\r\n9, 2021\r\n7 min read\r\nOpinions expressed by Entrepreneur contributors are their own.\r\nFor the blockchain sector, 2020 was the year of decentralized finance. While the rest of the world was gr… [+7394 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Tom Wilson',
#    'title': 'Bitcoin jumps to record $28,600 as 2020 rally reaches new heights - Reuters India',
#    'description': 'Bitcoin on Wednesday jumped to a record $28,599.99, after the digital currency almost quadrupled in value this year amid heightened interest from bigger investors.',
#    'url': 'https://in.reuters.com/article/us-crypto-currency-idINKBN2940X0',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20201230&t=2&i=1546143610&r=LYNXMPEGBT0H5&w=800',
#    'publishedAt': '2020-12-30T10:56:00Z',
#    'content': 'LONDON (Reuters) - Bitcoin on Wednesday jumped to a record $28,599.99, after the digital currency almost quadrupled in value this year amid heightened interest from bigger investors.\r\nThe worlds most… [+1092 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'David Randall',
#    'title': "Big tech bets and cryptocurrencies power 2020's top U.S. funds - Reuters Africa",
#    'description': "Outsized bets on large U.S. technology companies and emerging cryptocurrencies fueled the year's top-performing U.S. mutual fund and exchange-traded funds as the coronavirus pandemic upended global markets, while funds that bet on oil and gas companies fell n…",
#    'url': 'https://www.reuters.com/article/us-usa-funds-sectors-yearend-idUSKBN2920CG',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20201228&t=2&i=1545935468&r=LYNXMPEGBR05A&w=800',
#    'publishedAt': '2020-12-28T06:07:00Z',
#    'content': 'NEW YORK (Reuters) - Outsized bets on large U.S. technology companies and emerging cryptocurrencies fueled the years top-performing U.S. mutual fund and exchange-traded funds as the coronavirus pande… [+3726 chars]'},
#   {'source': {'id': 'ars-technica', 'name': 'Ars Technica'},
#    'author': 'Timothy B. Lee',
#    'title': 'The world’s cryptocurrency is now worth more than $1 trillion',
#    'description': "Bitcoin's anonymous founder, Satoshi Nakamoto, could be worth $40 billion.",
#    'url': 'https://arstechnica.com/tech-policy/2021/01/the-worlds-cryptocurrency-is-now-worth-more-than-1-trillion/',
#    'urlToImage': 'https://cdn.arstechnica.net/wp-content/uploads/2014/11/bitcoin-640x215.jpg',
#    'publishedAt': '2021-01-07T17:30:27Z',
#    'content': "1 with 1 posters participating\r\nThe world's cryptocurrency is now worth more than $1 trillion, with bitcoin accounting for a large majority of the value. The price of the oldest virtual currency has … [+1174 chars]"},
#   {'source': {'id': None, 'name': 'Android Central'},
#    'author': 'StackSocial',
#    'title': 'Become an expert cryptocurrency investor with this bundle of six courses for $30',
#    'description': 'Source: StackCommerce\nWhen the price of Bitcoin maxed out, you might have thought the cryptocurrency bubble had burst. In fact, there are still many digital currencies gaining value.\xa0The Complete Cryptocurrency Professional Trading Bundle\xa0shows you how to rid…',
#    'url': 'https://www.androidcentral.com/become-expert-cryptocurrency-investor-bundle-six-courses-30',
#    'urlToImage': 'https://www.androidcentral.com/sites/androidcentral.com/files/styles/large/public/field/image/2020/12/sale_159885_article_image-2nqh.jpg',
#    'publishedAt': '2020-12-27T18:03:02Z',
#    'content': 'Source: StackCommerce\r\nWhen the price of Bitcoin maxed out, you might have thought the cryptocurrency bubble had burst. In fact, there are still many digital currencies gaining value.\xa0The Complete Cr… [+1002 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'Crypto trading volumes hit record $68.3 billion on Monday - CryptoCompare - Reuters UK',
#    'description': "Trading volumes on major cryptocurrency exchanges hit a daily record on Monday of over $68 billion, research showed, highlighting the trading frenzy that has accompanied bitcoin's charge to an all-time high.",
#    'url': 'https://www.reuters.com/article/us-crypto-currency-idUKKBN29A1N6',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210105&t=2&i=1546668985&r=LYNXMPEH040V2&w=800',
#    'publishedAt': '2021-01-05T14:43:00Z',
#    'content': 'By Reuters Staff\r\nFILE PHOTO: Representations of virtual currency Bitcoin are seen in this picture illustration taken taken March 13, 2020. REUTERS/Dado Ruvic\r\nLONDON (Reuters) - Trading volumes on m… [+1327 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'Crypto market cap surges above $1 trillion for first time - Reuters UK',
#    'description': 'The total market value of all cryptocurrencies rose above $1 trillion for the first time on Thursday as Bitcoin surged to a record high, according to data by crypto coin trackers CoinMarketCap and CoinGecko.',
#    'url': 'https://uk.reuters.com/article/uk-crypto-currency-idUKKBN29C26G',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210107&t=2&i=1546985630&r=LYNXMPEH0613E&w=800',
#    'publishedAt': '2021-01-07T15:56:00Z',
#    'content': 'By Reuters Staff\r\nFILE PHOTO: Representations of virtual currency Bitcoin are seen in this picture illustration taken taken March 13, 2020. REUTERS/Dado Ruvic/Illustration\r\n(Reuters) - The total mark… [+1344 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'Crypto market cap surges above $1 trillion for first time - Reuters',
#    'description': 'The total market value of all cryptocurrencies rose above $1 trillion for the first time on Thursday as Bitcoin surged to a record high, according to data by crypto coin trackers CoinMarketCap and CoinGecko.',
#    'url': 'https://www.reuters.com/article/crypto-currency-int-idUSKBN29C264',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210107&t=2&i=1546977120&r=LYNXMPEH06139&w=800',
#    'publishedAt': '2021-01-07T15:54:00Z',
#    'content': 'By Reuters Staff\r\nFILE PHOTO: Representations of virtual currency Bitcoin are placed on U.S. Dollar banknotes in this illustration taken May 26, 2020. REUTERS/Dado Ruvic/Illustration/File Photo\r\n(Reu… [+1366 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'Crypto trading volumes hit record $68.3 billion on Monday - CryptoCompare - Reuters India',
#    'description': "Trading volumes on major cryptocurrency exchanges hit a daily record on Monday of over $68 billion, research showed, highlighting the trading frenzy that has accompanied bitcoin's charge to an all-time high.",
#    'url': 'https://in.reuters.com/article/crypto-currencies-flows-idINKBN29A1W5',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210105&t=2&i=1546677712&r=LYNXMPEH0410C&w=800',
#    'publishedAt': '2021-01-05T16:04:00Z',
#    'content': 'By Reuters Staff\r\nFILE PHOTO: A representation of virtual currency bitcoin is seen in front of a stock graph in this illustration taken November 19, 2020. REUTERS/Dado Ruvic/Illustration/File Photo\r\n… [+1366 chars]'}]}

# %%
# Fetch the LTC - Litecoin news articles
lite_headlines = newsapi.get_everything(q="litecoin",
                                        language="en",
                                        sort_by="relevancy")
lite_headlines
# Out:
# {'status': 'ok',
#  'totalResults': 338,
#  'articles': [{'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'Cryptocurrency XRP drops 18% after U.S. SEC charges Ripple over offering - Reuters India',
#    'description': 'Cryptocurrency XRP tumbled 18% to a one-month low on Wednesday after the U.S. Securities and Exchange Commission (SEC) charged associated blockchain firm Ripple with conducting a $1.3 billion unregistered securities offering.',
#    'url': 'https://in.reuters.com/article/us-crypto-currency-ripple-idINKBN28X116',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20201223&t=2&i=1545538377&r=LYNXMPEGBM0JQ&w=800',
#    'publishedAt': '2020-12-23T09:22:00Z',
#    'content': 'By Reuters Staff\r\nFILE PHOTO: Representations of the Ripple, Bitcoin, Etherum and Litecoin virtual currencies are seen on a PC motherboard in this illustration picture, February 14, 2018. REUTERS/Dad… [+301 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'Cryptocurrency XRP drops 18% after U.S. SEC charges Ripple over offering - Reuters',
#    'description': 'Cryptocurrency XRP tumbled 18% to a one-month low on Wednesday after the U.S. Securities and Exchange Commission (SEC) charged associated blockchain firm Ripple with conducting a $1.3 billion unregistered securities offering.',
#    'url': 'https://www.reuters.com/article/us-crypto-currency-ripple-idUSKBN28X116',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20201223&t=2&i=1545538377&r=LYNXMPEGBM0JQ&w=800',
#    'publishedAt': '2020-12-23T09:23:00Z',
#    'content': 'By Reuters Staff\r\nFILE PHOTO: Representations of the Ripple, Bitcoin, Etherum and Litecoin virtual currencies are seen on a PC motherboard in this illustration picture, February 14, 2018. REUTERS/Dad… [+301 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'XRP cryptocurrency slumps 16% as Coinbase exchange moves to suspend trading - Reuters UK',
#    'description': 'Cryptocurrency XRP slumped 16% on Tuesday after major U.S. virtual coin exchange Coinbase said it would suspend trading in the digital currency.',
#    'url': 'https://uk.reuters.com/article/uk-crypto-currency-idUKKBN2930WX',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20201229&t=2&i=1546042928&r=LYNXMPEGBS0GK&w=800',
#    'publishedAt': '2020-12-29T11:25:00Z',
#    'content': 'By Reuters Staff\r\nFILE PHOTO: Representations of the Ripple, Bitcoin, Etherum and Litecoin virtual currencies are seen on a PC motherboard in this illustration picture, February 14, 2018. REUTERS/Dad… [+623 chars]'},
#   {'source': {'id': 'ars-technica', 'name': 'Ars Technica'},
#    'author': 'Timothy B. Lee',
#    'title': 'The world’s cryptocurrency is now worth more than $1 trillion',
#    'description': "Bitcoin's anonymous founder, Satoshi Nakamoto, could be worth $40 billion.",
#    'url': 'https://arstechnica.com/tech-policy/2021/01/the-worlds-cryptocurrency-is-now-worth-more-than-1-trillion/',
#    'urlToImage': 'https://cdn.arstechnica.net/wp-content/uploads/2014/11/bitcoin-640x215.jpg',
#    'publishedAt': '2021-01-07T17:30:27Z',
#    'content': "1 with 1 posters participating\r\nThe world's cryptocurrency is now worth more than $1 trillion, with bitcoin accounting for a large majority of the value. The price of the oldest virtual currency has … [+1174 chars]"},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'Cryptocurrency XRP tumbles 24% after U.S. SEC charges Ripple - Reuters UK',
#    'description': 'Cryptocurrency XRP <XRP=BTSP> tumbled 24% on Wednesday after the U.S. Securities and Exchange Commission (SEC) charged associated blockchain firm Ripple with conducting a $1.3 billion unregistered securities offering.',
#    'url': 'https://in.reuters.com/article/us-crypto-currency-ripple-idUKKBN28X116',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20201223&t=2&i=1545538377&r=LYNXMPEGBM0JQ&w=800',
#    'publishedAt': '2020-12-23T09:26:00Z',
#    'content': 'By Reuters Staff\r\nFILE PHOTO: Representations of the Ripple, Bitcoin, Etherum and Litecoin virtual currencies are seen on a PC motherboard in this illustration picture, February 14, 2018. REUTERS/Dad… [+1197 chars]'},
#   {'source': {'id': None, 'name': 'Android Central'},
#    'author': 'StackSocial',
#    'title': 'Become an expert cryptocurrency investor with this bundle of six courses for $30',
#    'description': 'Source: StackCommerce\nWhen the price of Bitcoin maxed out, you might have thought the cryptocurrency bubble had burst. In fact, there are still many digital currencies gaining value.\xa0The Complete Cryptocurrency Professional Trading Bundle\xa0shows you how to rid…',
#    'url': 'https://www.androidcentral.com/become-expert-cryptocurrency-investor-bundle-six-courses-30',
#    'urlToImage': 'https://www.androidcentral.com/sites/androidcentral.com/files/styles/large/public/field/image/2020/12/sale_159885_article_image-2nqh.jpg',
#    'publishedAt': '2020-12-27T18:03:02Z',
#    'content': 'Source: StackCommerce\r\nWhen the price of Bitcoin maxed out, you might have thought the cryptocurrency bubble had burst. In fact, there are still many digital currencies gaining value.\xa0The Complete Cr… [+1002 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Dan Whateley',
#    'title': 'Bitcoin crosses $30,000 for the first time as it charges into 2021',
#    'description': 'Summary List PlacementThe price of bitcoin crossed $30,000 for the first time on Saturday as the digital currency continued its rally into the new year.\xa0\nBitcoin reached a high of $33,136.92, a spike of around 14% over the last 24 hours.\nThe cryptocurrency ha…',
#    'url': 'https://www.businessinsider.com/bitcoin-crosses-30000-as-it-continues-to-break-records-2021-1',
#    'urlToImage': 'https://i.insider.com/5fe5e0dda6448800181935ea?width=1200&format=jpeg',
#    'publishedAt': '2021-01-02T19:46:10Z',
#    'content': 'The price of bitcoin crossed $30,000 for the first time on Saturday as the digital currency continued its rally into the new year.\xa0\r\nBitcoin reached a high of $33,136.92, a spike of around 14% over t… [+1392 chars]'},
#   {'source': {'id': None, 'name': 'Seeking Alpha'},
#    'author': None,
#    'title': 'Bit Digital leads crypto-related weakness amid short seller report - Seeking Alpha',
#    'description': 'Bit Digital (NASDAQ:BTBT) dropped 26% amidst a selloff in Bitcoin-related companies today and following a new shortseller report.Earlier, nearly $170B was wiped off cryptocurrency market in as Bitcoin (BTC-USD)\xa0dropped 20.1%\xa0to $34,130 after a huge\xa0rally and …',
#    'url': 'https://seekingalpha.com/news/3650451-bit-digital-leads-crypto-related-weakness-amid-short-seller-report',
#    'urlToImage': 'https://static3.seekingalpha.com/assets/og_image_192-59bfd51c9fe6af025b2f9f96c807e46f8e2f06c5ae787b15bf1423e6c676d4db.png',
#    'publishedAt': '2021-01-11T19:49:00Z',
#    'content': None},
#   {'source': {'id': 'ars-technica', 'name': 'Ars Technica'},
#    'author': 'Timothy B. Lee',
#    'title': 'Ether soars above $1,000 in broad cryptocurrency rally',
#    'description': 'The value of all cryptocurrencies in circulation is more than $850 billion.',
#    'url': 'https://arstechnica.com/tech-policy/2021/01/ether-soars-above-1000-in-broad-cryptocurrency-rally/',
#    'urlToImage': 'https://cdn.arstechnica.net/wp-content/uploads/2017/11/36490685544_09623d813d_z-640x380.jpg',
#    'publishedAt': '2021-01-04T17:08:27Z',
#    'content': 'Ethereum creator Vitalik Buterin.\r\n14 with 11 posters participating\r\nEther, the native currency of the Ethereum network and the second most valuable cryptocurrency, has soared above $1,000 for the fi… [+3015 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Amanda Cooper',
#    'title': 'The Crypto Market Is Now Worth More Than $1 Trillion for the First Time as Bitcoin Hits Record Above $38,000',
#    'description': 'The entire crypto market is now worth roughly half of what Apple is and more than the entire economy of Switzerland.',
#    'url': 'https://markets.businessinsider.com/currencies/news/bitcoin-price-cryptocurrency-market-cap-apple-record-high-2021-1-1029940052',
#    'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1610031352-bitcoin.jpg',
#    'publishedAt': '2021-01-07T14:56:42Z',
#    'content': 'January\r\n7, 2021\r\n3 min read\r\nThis story originally appeared on Business InsiderThe cryptocurrency market is now worth more than $1 trillion for the first time ever after the price of bitcoin surged … [+3329 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Amanda Cooper',
#    'title': 'Bitcoin falls to a one-week low, as a stronger dollar and investor nerves strip off nearly $140 billion in total cryptocurrency market cap',
#    'description': 'Summary List PlacementCryptocurrencies tumbled on Monday, wiping off nearly $140 billion in total market cap, as traders took profits on the spectacular rally so far this month, in light of a stronger dollar and growing political uncertainty.\nInvestors will b…',
#    'url': 'https://www.businessinsider.com/bitcoin-price-dollar-rally-politics-risk-trump-impeachment-ethereum-crypto-2021-1',
#    'urlToImage': 'https://images2.markets.businessinsider.com/5ffc2e2fbde805001980c18d?format=jpeg',
#    'publishedAt': '2021-01-11T11:17:51Z',
#    'content': 'Photo illustration of visual representations of digital cryptocurrencies\r\nYuriko Nakao/Getty Images\r\nCryptocurrencies tumbled on Monday, wiping off nearly $140 billion in total market cap, as traders… [+3376 chars]'},
#   {'source': {'id': None, 'name': 'Windows Central'},
#    'author': 'StackSocial',
#    'title': 'Become an expert cryptocurrency investor with this bundle of six courses for $30',
#    'description': 'Source: StackCommerce\nWhen the price of Bitcoin maxed out, you might have thought the cryptocurrency bubble had burst. In fact, there are still many digital currencies gaining value.\xa0The Complete Cryptocurrency Professional Trading Bundle\xa0shows you how to rid…',
#    'url': 'https://www.windowscentral.com/become-expert-cryptocurrency-investor-bundle-six-courses-30',
#    'urlToImage': 'https://www.windowscentral.com/sites/wpcentral.com/files/styles/large/public/field/image/2020/12/sale_159885_article_image-2nqh.jpg',
#    'publishedAt': '2020-12-27T18:00:02Z',
#    'content': 'Source: StackCommerce\r\nWhen the price of Bitcoin maxed out, you might have thought the cryptocurrency bubble had burst. In fact, there are still many digital currencies gaining value.\xa0The Complete Cr… [+1002 chars]'},
#   {'source': {'id': None, 'name': 'MarketWatch'},
#    'author': 'Barbara Kollmeyer',
#    'title': 'Cryptos: Bitcoin drops 13% after bullish start to 2021',
#    'description': 'Cryptocurrency investors were facing a rough start to the week, with bitcoin and fellow digital currencies getting hit hard by sellers.',
#    'url': 'https://www.marketwatch.com/story/bitcoin-drops-13-after-bullish-start-to-2021-11610358317',
#    'urlToImage': 'https://images.mktw.net/im-283325/social',
#    'publishedAt': '2021-01-11T09:45:00Z',
#    'content': 'What goes up must come down? Bitcoin investors may be asking themselves that question as the cryptocurrency fell sharply on Monday. The price of bitcoin \r\n BTCUSD,\r\n -6.52%\r\nwas last down 13% to $35,… [+2100 chars]'},
#   {'source': {'id': None, 'name': 'Forbes'},
#    'author': 'Billy Bambrough, Contributor, \n Billy Bambrough, Contributor\n https://www.forbes.com/sites/billybambrough/',
#    'title': 'Is This Why Bitcoin, Ethereum, Litecoin And Other Cryptocurrencies Have Suddenly Shot Higher?',
#    'description': 'The bitcoin price, breaking $28,000 per bitcoin for the first time ever over the Christmas weekend, has added over 50% this month—with other major tokens ethereum and litecoin surging along with it...',
#    'url': 'https://www.forbes.com/sites/billybambrough/2021/12/28/is-this-why-bitcoin-ethereum-litecoin-and-other-cryptocurrencies-have-suddenly-shot-higher/',
#    'urlToImage': 'https://thumbor.forbes.com/thumbor/fit-in/1200x0/filters%3Aformat%28jpg%29/https%3A%2F%2Fspecials-images.forbesimg.com%2Fimageserve%2F5fe9b1915699fc991df64e74%2F0x0.jpg',
#    'publishedAt': '2020-12-28T10:55:41Z',
#    'content': 'Bitcoin has continued its huge December rally over the last few days, climbing to a total value of around half a trillion dollars ($500 billion). \r\nThe bitcoin price, breaking $28,000 per bitcoin for… [+2998 chars]'},
#   {'source': {'id': None, 'name': 'MarketWatch'},
#    'author': 'Mark DeCambre',
#    'title': 'The Tell: Here’s how bitcoin could soon be worth $146,000 according to JPMorgan',
#    'description': 'JPMorgan researchers point to outflows from gold-pegged exchange traded funds, or ETFs, and inflows into a digital-currency focused trusts sponsored by Grayscale, for example, as part of the evidence pointing to increased use of bitcoin as a gold-like asset, …',
#    'url': 'https://www.marketwatch.com/story/heres-how-bitcoin-could-soon-be-worth-146-000-says-jpmorgan-11609869356',
#    'urlToImage': 'https://images.mktw.net/im-280789/social',
#    'publishedAt': '2021-01-05T18:04:00Z',
#    'content': 'Bitcoins nearly nonstop climb to new records has drawn the attention of Wall Street like few other securities in recent memory. The worlds No. 1 digital asset was recently trading at around $32,000 i… [+3472 chars]'},
#   {'source': {'id': None, 'name': 'Forbes'},
#    'author': 'Billy Bambrough, Contributor, \n Billy Bambrough, Contributor\n https://www.forbes.com/sites/billybambrough/',
#    'title': 'As Bitcoin, Ethereum, Ripple’s XRP And Litecoin Lose Billions, Watchdog Issues Stark Warning',
#    'description': 'As the bitcoin and cryptocurrency market wobbles, the U.K. financial watchdog has issued a stark to people considering trying to jump onto the crypto bandwagon—you "should be prepared to lose all their money"...',
#    'url': 'https://www.forbes.com/sites/billybambrough/2021/01/11/as-bitcoin-ethereum-ripples-xrp-and-litecoin-lose-billions-watchdog-issues-stark-warning/',
#    'urlToImage': 'https://thumbor.forbes.com/thumbor/fit-in/1200x0/filters%3Aformat%28jpg%29/https%3A%2F%2Fspecials-images.forbesimg.com%2Fimageserve%2F5ffc1bc883d0e8c00e070350%2F0x0.jpg',
#    'publishedAt': '2021-01-11T09:50:00Z',
#    'content': 'Bitcoin, after surging non-stop for the last few weeks, has finally taken a breather. \r\nThe bitcoin price has dropped around 15% in the last 24 hours, dragging down the wider cryptocurrency market an… [+4314 chars]'},
#   {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': 'Chris Markoch',
#    'title': 'The Party May Just Be Starting For Litecoin',
#    'description': 'Frequently known as the silver to bitcoin’s (CCC:BTC) gold, the time may be right for investors to invest in litecoin (CCC:LTC). One of the oldest altcoins, ...',
#    'url': 'https://finance.yahoo.com/news/party-may-just-starting-litecoin-182502232.html',
#    'urlToImage': 'https://s.yimg.com/uu/api/res/1.2/QGHkmnzxn5LViUBTKahP4A--~B/aD00MDA7dz03Mjg7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/investorplace_417/5cf0ba1ef486b3cd57d4ec70777e76b1',
#    'publishedAt': '2021-01-15T18:25:02Z',
#    'content': 'Frequently known as the silver to bitcoins (CCC:BTC) gold, the time may be right for investors to invest in litecoin (CCC:LTC). One of the oldest altcoins, litecoin has jumped over 85% since Dec. 10.… [+5042 chars]'},
#   {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': 'Bob Mason',
#    'title': 'Ethereum, Litecoin, and Ripple’s XRP – Daily Tech Analysis – January 13th, 2021',
#    'description': 'It’s a bearish start to the day for the majors. Failure to move through the day’s pivot levels would leave support levels in play.',
#    'url': 'https://finance.yahoo.com/news/ethereum-litecoin-ripple-xrp-daily-001921667.html',
#    'urlToImage': 'https://s.yimg.com/uu/api/res/1.2/Uc3MqFG5fv2PFZX.FPcb1Q--~B/aD00MTA7dz02MTU7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/fx_empire_176/3a57df7b01e97b345757d5e7291d135c',
#    'publishedAt': '2021-01-13T00:19:21Z',
#    'content': 'Ethereum\r\nEthereum fell by 3.56% on Tuesday. Following on from Mondays 13.25% tumble, Ethereum ended the day at $1,049.79.\r\nIt was a choppy day. Ethereum fell to an early morning low $1,040.00 before… [+5947 chars]'},
#   {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': 'Bob Mason',
#    'title': 'Ethereum, Litecoin, and Ripple’s XRP – Daily Tech Analysis – January 16th, 2021',
#    'description': 'It’s a bullish start to the day for the majors. A move through Friday’s highs would support a breakout on the day.',
#    'url': 'https://finance.yahoo.com/news/ethereum-litecoin-ripple-xrp-daily-002733695.html',
#    'urlToImage': 'https://s.yimg.com/uu/api/res/1.2/ZSONKx4tMF9lqYa.0XCxfw--~B/aD00MTA7dz02MTU7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/fx_empire_176/657cd4df227529d12b0dfdfad9feaa42',
#    'publishedAt': '2021-01-16T00:27:33Z',
#    'content': 'Ethereum\r\nEthereum slid by 5.16% on Friday. Partially reversing an 8.89% rally from Thursday, Ethereum ended the day at $1,168.1.\r\nA bullish start to the day saw Ethereum rise to an early morning int… [+5569 chars]'},
#   {'source': {'id': None, 'name': 'FX Empire'},
#    'author': None,
#    'title': "Ethereum, Litecoin, and Ripple's XRP – Daily Tech Analysis – December 25th, 2020 - FX Empire",
#    'description': 'It&#039;s a bearish start to the day for the majors. Steering clear of the day&#039;s pivot levels, however, would bring resistance levels into play.',
#    'url': 'https://www.fxempire.com/forecasts/article/ethereum-litecoin-and-ripples-xrp-daily-tech-analysis-december-25th-2020-690657',
#    'urlToImage': 'https://responsive.fxempire.com/width/600/webp-lossy-70.q50/_fxempire_/2020/12/All-Crypto-Coins-4.jpg',
#    'publishedAt': '2020-12-25T00:31:09Z',
#    'content': 'For the day ahead\r\nEthereum would need to avoid a fall through the pivot level at $597.62 to support a run at the first major resistance level at $629.64.\r\nSupport from the broader market would be ne… [+1718 chars]'}]}

# %%
# Create the S&P 500 sentiment scores DataFrame
spy_sentiments = []

for article in spy_headlines["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        spy_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
spy_sent_df = pd.DataFrame(spy_sentiments)

# Reorder DataFrame columns
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
spy_sent_df = spy_sent_df[cols]

spy_sent_df.head()
# Out:
#          date                                               text  compound  \
# 0  2021-01-14  Over the last few months, programmers speciali...    0.5423
# 1  2021-01-06  New York (CNN Business)The "blue wave" that ma...    0.0000
# 2  2021-01-10  (CNN Business)Apple removed Parler, the altern...   -0.7430
# 3  2021-01-04  A somewhat nebulous, but high-profile and pote...    0.5499
# 4  2020-12-29  An Apple spokesperson told the publication tha...    0.4215
#
#    positive  negative  neutral
# 0     0.123     0.000    0.877
# 1     0.000     0.000    1.000
# 2     0.070     0.228    0.702
# 3     0.136     0.000    0.864
# 4     0.085     0.000    0.915

# %%
# Create the Finance Sector sentiment scores DataFrame
financial_sentiments = []

for article in finance_headlines["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        financial_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
financial_sent_df = pd.DataFrame(financial_sentiments)

# Reorder DataFrame columns
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
financial_sent_df = financial_sent_df[cols]

financial_sent_df.head()
# Out:
#          date                                               text  compound  \
# 0  2021-01-12  Investors have been enthusiastic about large U...    0.7579
# 1  2021-01-12  Value stocks are set to outperform in 2021, as...    0.6124
# 2  2021-01-06  A financial windfall can come in many formsinh...    0.8689
# 3  2020-12-29  New Years resolutions typically fail when they...   -0.6801
# 4  2020-12-31  An investor looks at an electronic board showi...    0.0000
#
#    positive  negative  neutral
# 0     0.188     0.000    0.812
# 1     0.139     0.000    0.861
# 2     0.253     0.000    0.747
# 3     0.071     0.195    0.734
# 4     0.000     0.000    1.000

# %%
# Create the Technology Sector sentiment scores DataFrame
technology_sentiments = []

for article in tech_headlines["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        technology_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
technology_sent_df = pd.DataFrame(technology_sentiments)

# Reorder DataFrame columns
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
technology_sent_df = technology_sent_df[cols]

technology_sent_df.head()
# Out:
#          date                                               text  compound  \
# 0  2020-12-28  If ever there was a typically quiet tech indus...    0.0000
# 1  2020-12-25  But the CrowdStrike discovery shows how the Ru...    0.0000
# 2  2020-12-30  Security researchers looking to get under the ...    0.8225
# 3  2021-01-12  Plenty of new toys are being announced across ...    0.0772
# 4  2021-01-14  Hello and welcome back to Equity, TechCrunchs ...    0.7003
#
#    positive  negative  neutral
# 0     0.000       0.0    1.000
# 1     0.000       0.0    1.000
# 2     0.217       0.0    0.783
# 3     0.038       0.0    0.962
# 4     0.158       0.0    0.842

# %%
# Create the Telecom Sector sentiment scores DataFrame
telecom_sentiments = []

for article in telecom_headlines["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        telecom_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
telecom_sent_df = pd.DataFrame(telecom_sentiments)

# Reorder DataFrame columns
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
telecom_sent_df = telecom_sent_df[cols]

telecom_sent_df.head()
# Out:
#          date                                               text  compound  \
# 0  2021-01-07  The IdeaPad 5G’s 14-inch IPS display runs at a...    0.3818
# 1  2020-12-24  “Following a thorough review, Visa will reinst...    0.8020
# 2  2021-01-12  Regulatory action prompts Visa to back off a f...    0.4404
# 3  2021-01-11  We don’t normally see a lot of phones at CES, ...    0.5023
# 4  2021-01-14  Hello and welcome back to Equity, TechCrunchs ...    0.7003
#
#    positive  negative  neutral
# 0     0.069       0.0    0.931
# 1     0.240       0.0    0.760
# 2     0.079       0.0    0.921
# 3     0.083       0.0    0.917
# 4     0.158       0.0    0.842

# %%
# Create the Utilities Sector sentiment scores DataFrame
utility_sentiments = []

for article in utility_headlines["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        utility_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
utility_sent_df = pd.DataFrame(utility_sentiments)

# Reorder DataFrame columns
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
utility_sent_df = utility_sent_df[cols]

utility_sent_df.head()
# Out:
#          date                                               text  compound  \
# 0  2021-01-14  Hello and welcome back to Equity, TechCrunchs ...    0.7003
# 1  2021-01-12  Visa and Plaid called off their agreement this...    0.8271
# 2  2020-12-24  “Following a thorough review, Visa will reinst...    0.8020
# 3  2021-01-12  Regulatory action prompts Visa to back off a f...    0.4404
# 4  2021-01-13  More posts by this contributor\r\nHere’s anoth...    0.5859
#
#    positive  negative  neutral
# 0     0.158       0.0    0.842
# 1     0.214       0.0    0.786
# 2     0.240       0.0    0.760
# 3     0.079       0.0    0.921
# 4     0.146       0.0    0.854

# %%
# Create the Industrial Sector sentiment scores DataFrame
industrial_sentiments = []

for article in indust_headlines["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        industrial_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
industrial_sent_df = pd.DataFrame(industrial_sentiments)

# Reorder DataFrame columns
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
industrial_sent_df = industrial_sent_df[cols]

industrial_sent_df.head()
# Out:
#          date                                               text  compound  \
# 0  2021-01-05  Back in 2016, Amazon’s cargo air fleet (then k...    0.0000
# 1  2021-01-14  Ray Tracing and 4K are the most-talked-about c...    0.0000
# 2  2021-01-13  Nvidia just announced its entry-level 3000-ser...    0.6369
# 3  2021-01-12  Later today, Nvidias GeForce RTX: Game On live...    0.1779
# 4  2021-01-05  A thermostat is also in the works, GE Lighting...    0.4019
#
#    positive  negative  neutral
# 0     0.000     0.000    1.000
# 1     0.000     0.000    1.000
# 2     0.116     0.000    0.884
# 3     0.074     0.055    0.871
# 4     0.074     0.000    0.926

# %%
# Create the Healthcare Sector sentiment scores DataFrame
healthcare_sentiments = []

for article in health_headlines["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        healthcare_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
healthcare_sent_df = pd.DataFrame(healthcare_sentiments)

# Reorder DataFrame columns
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
healthcare_sent_df = healthcare_sent_df[cols]

healthcare_sent_df.head()
# Out:
#          date                                               text  compound  \
# 0  2020-12-22  According to a report last month by the Govern...    0.2023
# 1  2021-01-04  Further steps must now be taken to arrest this...    0.7096
# 2  2021-01-04  Further steps must now be taken to arrest this...    0.7096
# 3  2020-12-22  According to a report last month by the Govern...    0.2023
# 4  2020-12-24  SEOUL (Reuters) -South Korea has signed deals ...    0.3400
#
#    positive  negative  neutral
# 0     0.091     0.000    0.909
# 1     0.194     0.056    0.749
# 2     0.194     0.056    0.749
# 3     0.091     0.000    0.909
# 4     0.074     0.000    0.926

# %%
# Create the Energy Sector sentiment scores DataFrame
energy_sentiments = []

for article in energy_headlines["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        energy_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
energy_sent_df = pd.DataFrame(energy_sentiments)

# Reorder DataFrame columns
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
energy_sent_df = energy_sent_df[cols]

energy_sent_df.head()
# Out:
#          date                                               text  compound  \
# 0  2021-01-20  Most energy analysts would call 2020 an unprec...   -0.4951
# 1  2021-01-13  By Reuters Staff\r\n(Reuters) - J.P. Morgan an...   -0.0772
# 2  2021-01-07  WASHINGTON (Reuters) - The head of a major U.S...    0.0000
# 3  2021-01-07  WASHINGTON (Reuters) - The head of a major U.S...    0.0000
# 4  2021-01-06  (Adds more business groups)\r\nWASHINGTON, Jan...    0.0000
#
#    positive  negative  neutral
# 0     0.157     0.207    0.636
# 1     0.060     0.068    0.872
# 2     0.000     0.000    1.000
# 3     0.000     0.000    1.000
# 4     0.000     0.000    1.000

# %%
# Create the Ethereum sentiment scores DataFrame
ethereum_sentiments = []

for article in ethereum_headlines["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        ethereum_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
ethereum_sent_df = pd.DataFrame(ethereum_sentiments)

# Reorder DataFrame columns
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
ethereum_sent_df = ethereum_sent_df[cols]

ethereum_sent_df.head()
# Out:
#          date                                               text  compound  \
# 0  2021-01-05  Cryptocurrencies stole headlines on the first ...    0.3412
# 1  2021-01-04  Ethereum creator Vitalik Buterin.\r\n14 with 1...    0.5256
# 2  2021-01-04  Bitcoin fizzled in Monday trading as the famou...   -0.2732
# 3  2021-01-08  By Reuters Staff\r\nFILE PHOTO: A representati...    0.0000
# 4  2021-01-08  By Reuters Staff\r\nFILE PHOTO: A representati...    0.0000
#
#    positive  negative  neutral
# 0     0.074      0.00    0.926
# 1     0.099      0.00    0.901
# 2     0.000      0.06    0.940
# 3     0.000      0.00    1.000
# 4     0.000      0.00    1.000

# %%
# Create the Litecoin sentiment scores DataFrame
litecoin_sentiments = []

for article in lite_headlines["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        litecoin_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
litecoin_sent_df = pd.DataFrame(litecoin_sentiments)

# Reorder DataFrame columns
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
litecoin_sent_df = litecoin_sent_df[cols]

litecoin_sent_df.head()
# Out:
#          date                                               text  compound  \
# 0  2020-12-23  By Reuters Staff\r\nFILE PHOTO: Representation...    0.0000
# 1  2020-12-23  By Reuters Staff\r\nFILE PHOTO: Representation...    0.0000
# 2  2020-12-29  By Reuters Staff\r\nFILE PHOTO: Representation...    0.0000
# 3  2021-01-07  1 with 1 posters participating\r\nThe world's ...    0.5106
# 4  2020-12-23  By Reuters Staff\r\nFILE PHOTO: Representation...    0.0000
#
#    positive  negative  neutral
# 0     0.000       0.0    1.000
# 1     0.000       0.0    1.000
# 2     0.000       0.0    1.000
# 3     0.125       0.0    0.875
# 4     0.000       0.0    1.000

# %%
# Describe the S&P 500 Sentiment
spy_sent_df.describe()
# Out:
#         compound   positive   negative    neutral
# count  20.000000  20.000000  20.000000  20.000000
# mean    0.038685   0.063550   0.045550   0.890800
# std     0.515244   0.076075   0.077708   0.100519
# min    -0.798200   0.000000   0.000000   0.675000
# 25%    -0.296000   0.000000   0.000000   0.852500
# 50%     0.000000   0.040500   0.000000   0.905000
# 75%     0.544200   0.109500   0.060500   0.971500
# max     0.877700   0.246000   0.245000   1.000000

# %%
# Describe the Finance Sector Sentiment
financial_sent_df.describe()
# Out:
#         compound   positive   negative    neutral
# count  20.000000  20.000000  20.000000  20.000000
# mean    0.198580   0.069600   0.018700   0.911750
# std     0.360879   0.083562   0.047526   0.102904
# min    -0.680100   0.000000   0.000000   0.722000
# 25%     0.000000   0.000000   0.000000   0.842000
# 50%     0.000000   0.025000   0.000000   0.975000
# 75%     0.496125   0.143750   0.000000   1.000000
# max     0.868900   0.253000   0.195000   1.000000

# %%
# Describe the Technology Sector Sentiment
technology_sent_df.describe()
# Out:
#        compound   positive   negative    neutral
# count  20.00000  20.000000  20.000000  20.000000
# mean    0.30327   0.081650   0.010350   0.908000
# std     0.33927   0.082376   0.035531   0.097145
# min    -0.29600   0.000000   0.000000   0.650000
# 25%     0.00000   0.000000   0.000000   0.873500
# 50%     0.24805   0.065000   0.000000   0.935000
# 75%     0.62490   0.126500   0.000000   1.000000
# max     0.87770   0.246000   0.152000   1.000000

# %%
# Describe the Telecom Sector Sentiment
telecom_sent_df.describe()
# Out:
#         compound   positive   negative    neutral
# count  20.000000  20.000000  20.000000  20.000000
# mean    0.295115   0.083300   0.019250   0.897450
# std     0.407197   0.070188   0.047294   0.068155
# min    -0.827100   0.000000   0.000000   0.760000
# 25%     0.000000   0.036750   0.000000   0.853000
# 50%     0.391850   0.075000   0.000000   0.918000
# 75%     0.595650   0.123500   0.000000   0.931250
# max     0.827100   0.240000   0.194000   1.000000

# %%
# Describe the Utilities Sector Sentiment
utility_sent_df.describe()
# Out:
#         compound   positive   negative    neutral
# count  20.000000  20.000000  20.000000  20.000000
# mean    0.265130   0.107700   0.046250   0.846050
# std     0.529517   0.076197   0.093193   0.085955
# min    -0.948400   0.000000   0.000000   0.623000
# 25%    -0.114475   0.062250   0.000000   0.783500
# 50%     0.411100   0.085000   0.000000   0.852000
# 75%     0.652750   0.161500   0.059000   0.916500
# max     0.839300   0.240000   0.377000   0.958000

# %%
# Describe the Industrial Sector Sentiment
industrial_sent_df.describe()
# Out:
#         compound   positive   negative    neutral
# count  18.000000  18.000000  18.000000  18.000000
# mean    0.151667   0.053444   0.020000   0.926556
# std     0.336103   0.046527   0.035795   0.060402
# min    -0.659700   0.000000   0.000000   0.820000
# 25%     0.000000   0.000000   0.000000   0.884000
# 50%     0.128000   0.049000   0.000000   0.927500
# 75%     0.391725   0.088250   0.040500   0.987750
# max     0.636900   0.120000   0.120000   1.000000

# %%
# Describe the Healthcare Sector Sentiment
healthcare_sent_df.describe()
# Out:
#         compound   positive   negative    neutral
# count  20.000000  20.000000  20.000000  20.000000
# mean    0.235810   0.065950   0.012300   0.921600
# std     0.284768   0.064212   0.025532   0.077502
# min    -0.202300   0.000000   0.000000   0.749000
# 25%     0.000000   0.000000   0.000000   0.894750
# 50%     0.202300   0.062000   0.000000   0.938000
# 75%     0.397975   0.092250   0.000000   1.000000
# max     0.709600   0.194000   0.076000   1.000000

# %%
# Describe the Energy Sector Sentiment
energy_sent_df.describe()
# Out:
#         compound   positive   negative   neutral
# count  20.000000  20.000000  20.000000  20.00000
# mean   -0.014835   0.030500   0.030650   0.93885
# std     0.273764   0.057088   0.052428   0.09441
# min    -0.495100   0.000000   0.000000   0.63600
# 25%    -0.108475   0.000000   0.000000   0.91850
# 50%     0.000000   0.000000   0.000000   1.00000
# 75%     0.000000   0.015000   0.060000   1.00000
# max     0.718400   0.157000   0.207000   1.00000

# %%
# Describe the Ethereum Sector Sentiment
ethereum_sent_df.describe()
# Out:
#         compound   positive   negative    neutral
# count  19.000000  19.000000  19.000000  19.000000
# mean    0.089084   0.031421   0.009789   0.958789
# std     0.299285   0.056226   0.023273   0.055260
# min    -0.381800   0.000000   0.000000   0.845000
# 25%     0.000000   0.000000   0.000000   0.929500
# 50%     0.000000   0.000000   0.000000   1.000000
# 75%     0.170600   0.037000   0.000000   1.000000
# max     0.636900   0.155000   0.067000   1.000000

# %%
# Describe the Litecoin Sentiment
litecoin_sent_df.describe()
# Out:
#         compound   positive   negative    neutral
# count  19.000000  19.000000  19.000000  19.000000
# mean    0.212842   0.054947   0.008789   0.936211
# std     0.295330   0.066625   0.020893   0.075552
# min    -0.273200   0.000000   0.000000   0.767000
# 25%     0.000000   0.000000   0.000000   0.871500
# 50%     0.000000   0.000000   0.000000   0.962000
# 75%     0.518100   0.127500   0.000000   1.000000
# max     0.636900   0.178000   0.060000   1.000000

# %% [markdown]
# ---
